# %%
import random
import time

import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# settings
env_id  = "CartPole-v1"

# number of environments to run in parallel
num_envs = 1

# total number of timesteps for training over multiple episodes
total_timesteps = 100_000

# adam learning rate
learning_rate = 1e-3

# discount factor
gamma = 0.99

# epsilon value for epsilon-greedy (prob of choosing a random action)
eps = 0.1

# optional: set seed for reproducibility
# seed = 123
seed = None

video_path = "qlearning_cartpole_videos"

# %%
def make_env(env_id, capture_video, seed=None):
  if capture_video:
    env = gym.make(env_id, render_mode="rgb_array")
    env = gym.wrappers.RecordVideo(env, video_path,
            episode_trigger=lambda episode: True)
  else:
    env = gym.make(env_id)
  env = gym.wrappers.RecordEpisodeStatistics(env)

  if seed is not None:
    env.action_space.seed(seed)
  return env

# %%
class QNetwork(nn.Module):
  def __init__(self, envs, n_hidden=128):
    super().__init__()
    self.network = nn.Sequential(
      nn.Linear(np.array(envs.single_observation_space.shape).prod(), n_hidden),
      nn.ReLU(),
      nn.Linear(n_hidden, envs.single_action_space.n)
    )

  def forward(self, x):
    return self.network(x)

# %%
# optional: set seeds for reproducibility
# random.seed(seed)
# np.random.seed(seed)
# torch.manual_seed(seed)
# torch.backends.cudnn.deterministic = True

# %%
# make environments
envs = gym.vector.SyncVectorEnv([
  lambda: make_env(
      env_id,
      capture_video=False,
      seed=seed if seed is None else seed + i)
  for i in range(num_envs)
])

# %%
device = torch.device(
    "cuda" if torch.cuda.is_available() else
    "mps" if torch.backends.mps.is_available() else
    "cpu"
)

# %%
# make neural networks
q_network = QNetwork(envs).to(device)
optimizer = optim.Adam(q_network.parameters(), lr=learning_rate)

# %%
def np2torch(a):
  return torch.as_tensor(a, dtype=torch.float32, device=device)

# %%
# training loop

episode_returns = []
losses = []

start_time = time.time()
obs, _ = envs.reset(seed=seed)
autoreset = np.zeros(num_envs, dtype=bool)

for global_step in range(total_timesteps):

  # select action based on epsilon-greedy strategy
  if random.random() < eps:
    actions = np.array(
        [envs.single_action_space.sample() for _ in range(num_envs)])
  else:
    q_values = q_network(np2torch(obs))
    actions = torch.argmax(q_values, dim=1).cpu().numpy()

  # take a step in the environment
  next_obs, rewards, dones, truncateds, infos = envs.step(actions)

  # record returns for plotting
  for i, (done, truncated) in enumerate(zip(dones, truncateds)):
    if done or truncated:
      ret = infos['episode']['r'][i]
      episode_returns.append(ret)
      print(f"global_step={global_step}, episode={len(episode_returns)}, episode_return={ret}")

  # training
  # use only envs that haven't been autoreset
  mask = np.logical_not(autoreset)
  obs_ = obs[mask]
  actions_ = actions[mask]
  rewards_ = rewards[mask]
  next_obs_ = next_obs[mask]
  dones_ = dones[mask]
  if np.any(mask):
    with torch.no_grad():
      q_next, _ = q_network(np2torch(next_obs_)).max(dim=1)
      td_target = np2torch(rewards_) + gamma * (1 - np2torch(dones_)) * q_next
    pred = q_network(np2torch(obs_)).gather(
        1, torch.from_numpy(actions_.reshape(-1, 1)).to(device))

    loss = F.mse_loss(td_target.squeeze(), pred.squeeze())
    losses.append(loss.detach().cpu().numpy())

    # optimize
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

  # don't forget
  obs = next_obs

  # update autoreset
  autoreset = np.logical_or(dones, truncateds)

  if global_step % 1000 == 0:
    print("steps per second:", int(global_step / (time.time() - start_time)))

  # let's break if the last 10 episodes had max reward
  if len(episode_returns) > 10 and np.all(np.equal(episode_returns[-10:], 500)):
    print("max reward achieved")
    break
# Out:
# steps per second: 0
# global_step=15, episode=1, episode_return=16.0
# global_step=25, episode=2, episode_return=9.0
# global_step=35, episode=3, episode_return=9.0
# global_step=46, episode=4, episode_return=10.0
# global_step=56, episode=5, episode_return=9.0
# global_step=71, episode=6, episode_return=14.0
# global_step=81, episode=7, episode_return=9.0
# global_step=93, episode=8, episode_return=11.0
# global_step=104, episode=9, episode_return=10.0
# global_step=117, episode=10, episode_return=12.0
# global_step=127, episode=11, episode_return=9.0
# global_step=138, episode=12, episode_return=10.0
# global_step=148, episode=13, episode_return=9.0
# global_step=160, episode=14, episode_return=11.0
# global_step=171, episode=15, episode_return=10.0
# global_step=181, episode=16, episode_return=9.0
# global_step=193, episode=17, episode_return=11.0
# global_step=203, episode=18, episode_return=9.0
# global_step=215, episode=19, episode_return=11.0
# global_step=226, episode=20, episode_return=10.0
# global_step=237, episode=21, episode_return=10.0
# global_step=247, episode=22, episode_return=9.0
# global_step=257, episode=23, episode_return=9.0
# global_step=268, episode=24, episode_return=10.0
# global_step=280, episode=25, episode_return=11.0
# global_step=291, episode=26, episode_return=10.0
# global_step=303, episode=27, episode_return=11.0
# global_step=314, episode=28, episode_return=10.0
# global_step=324, episode=29, episode_return=9.0
# global_step=335, episode=30, episode_return=10.0
# global_step=344, episode=31, episode_return=8.0
# global_step=354, episode=32, episode_return=9.0
# global_step=365, episode=33, episode_return=10.0
# global_step=375, episode=34, episode_return=9.0
# global_step=386, episode=35, episode_return=10.0
# global_step=396, episode=36, episode_return=9.0
# global_step=407, episode=37, episode_return=10.0
# global_step=417, episode=38, episode_return=9.0
# global_step=428, episode=39, episode_return=10.0
# global_step=441, episode=40, episode_return=12.0
# global_step=450, episode=41, episode_return=8.0
# global_step=461, episode=42, episode_return=10.0
# global_step=471, episode=43, episode_return=9.0
# global_step=482, episode=44, episode_return=10.0
# global_step=494, episode=45, episode_return=11.0
# global_step=506, episode=46, episode_return=11.0
# global_step=517, episode=47, episode_return=10.0
# global_step=529, episode=48, episode_return=11.0
# global_step=543, episode=49, episode_return=13.0
# global_step=552, episode=50, episode_return=8.0
# global_step=564, episode=51, episode_return=11.0
# global_step=575, episode=52, episode_return=10.0
# global_step=587, episode=53, episode_return=11.0
# global_step=598, episode=54, episode_return=10.0
# global_step=608, episode=55, episode_return=9.0
# global_step=618, episode=56, episode_return=9.0
# global_step=627, episode=57, episode_return=8.0
# global_step=638, episode=58, episode_return=10.0
# global_step=647, episode=59, episode_return=8.0
# global_step=658, episode=60, episode_return=10.0
# global_step=670, episode=61, episode_return=11.0
# global_step=680, episode=62, episode_return=9.0
# global_step=695, episode=63, episode_return=14.0
# global_step=705, episode=64, episode_return=9.0
# global_step=716, episode=65, episode_return=10.0
# global_step=725, episode=66, episode_return=8.0
# global_step=735, episode=67, episode_return=9.0
# global_step=747, episode=68, episode_return=11.0
# global_step=759, episode=69, episode_return=11.0
# global_step=769, episode=70, episode_return=9.0
# global_step=782, episode=71, episode_return=12.0
# global_step=792, episode=72, episode_return=9.0
# global_step=806, episode=73, episode_return=13.0
# global_step=817, episode=74, episode_return=10.0
# global_step=830, episode=75, episode_return=12.0
# global_step=839, episode=76, episode_return=8.0
# global_step=852, episode=77, episode_return=12.0
# global_step=865, episode=78, episode_return=12.0
# global_step=876, episode=79, episode_return=10.0
# global_step=886, episode=80, episode_return=9.0
# global_step=896, episode=81, episode_return=9.0
# global_step=907, episode=82, episode_return=10.0
# global_step=918, episode=83, episode_return=10.0
# global_step=929, episode=84, episode_return=10.0
# global_step=940, episode=85, episode_return=10.0
# global_step=954, episode=86, episode_return=13.0
# global_step=965, episode=87, episode_return=10.0
# global_step=974, episode=88, episode_return=8.0
# global_step=987, episode=89, episode_return=12.0
# global_step=997, episode=90, episode_return=9.0
# steps per second: 480
# global_step=1008, episode=91, episode_return=10.0
# global_step=1019, episode=92, episode_return=10.0
# global_step=1031, episode=93, episode_return=11.0
# global_step=1042, episode=94, episode_return=10.0
# global_step=1053, episode=95, episode_return=10.0
# global_step=1064, episode=96, episode_return=10.0
# global_step=1073, episode=97, episode_return=8.0
# global_step=1082, episode=98, episode_return=8.0
# global_step=1094, episode=99, episode_return=11.0
# global_step=1105, episode=100, episode_return=10.0
# global_step=1116, episode=101, episode_return=10.0
# global_step=1126, episode=102, episode_return=9.0
# global_step=1137, episode=103, episode_return=10.0
# global_step=1147, episode=104, episode_return=9.0
# global_step=1159, episode=105, episode_return=11.0
# global_step=1169, episode=106, episode_return=9.0
# global_step=1181, episode=107, episode_return=11.0
# global_step=1191, episode=108, episode_return=9.0
# global_step=1201, episode=109, episode_return=9.0
# global_step=1215, episode=110, episode_return=13.0
# global_step=1226, episode=111, episode_return=10.0
# global_step=1238, episode=112, episode_return=11.0
# global_step=1250, episode=113, episode_return=11.0
# global_step=1264, episode=114, episode_return=13.0
# global_step=1277, episode=115, episode_return=12.0
# global_step=1289, episode=116, episode_return=11.0
# global_step=1301, episode=117, episode_return=11.0
# global_step=1313, episode=118, episode_return=11.0
# global_step=1325, episode=119, episode_return=11.0
# global_step=1344, episode=120, episode_return=18.0
# global_step=1366, episode=121, episode_return=21.0
# global_step=1422, episode=122, episode_return=55.0
# global_step=1467, episode=123, episode_return=44.0
# global_step=1487, episode=124, episode_return=19.0
# global_step=1498, episode=125, episode_return=10.0
# global_step=1509, episode=126, episode_return=10.0
# global_step=1521, episode=127, episode_return=11.0
# global_step=1531, episode=128, episode_return=9.0
# global_step=1542, episode=129, episode_return=10.0
# global_step=1552, episode=130, episode_return=9.0
# global_step=1561, episode=131, episode_return=8.0
# global_step=1571, episode=132, episode_return=9.0
# global_step=1583, episode=133, episode_return=11.0
# global_step=1594, episode=134, episode_return=10.0
# global_step=1606, episode=135, episode_return=11.0
# global_step=1617, episode=136, episode_return=10.0
# global_step=1627, episode=137, episode_return=9.0
# global_step=1639, episode=138, episode_return=11.0
# global_step=1650, episode=139, episode_return=10.0
# global_step=1660, episode=140, episode_return=9.0
# global_step=1669, episode=141, episode_return=8.0
# global_step=1681, episode=142, episode_return=11.0
# global_step=1692, episode=143, episode_return=10.0
# global_step=1704, episode=144, episode_return=11.0
# global_step=1723, episode=145, episode_return=18.0
# global_step=1736, episode=146, episode_return=12.0
# global_step=1746, episode=147, episode_return=9.0
# global_step=1761, episode=148, episode_return=14.0
# global_step=1775, episode=149, episode_return=13.0
# global_step=1786, episode=150, episode_return=10.0
# global_step=1799, episode=151, episode_return=12.0
# global_step=1811, episode=152, episode_return=11.0
# global_step=1826, episode=153, episode_return=14.0
# global_step=1839, episode=154, episode_return=12.0
# global_step=1850, episode=155, episode_return=10.0
# global_step=1862, episode=156, episode_return=11.0
# global_step=1873, episode=157, episode_return=10.0
# global_step=1884, episode=158, episode_return=10.0
# global_step=1894, episode=159, episode_return=9.0
# global_step=1908, episode=160, episode_return=13.0
# global_step=1921, episode=161, episode_return=12.0
# global_step=1932, episode=162, episode_return=10.0
# global_step=1943, episode=163, episode_return=10.0
# global_step=1955, episode=164, episode_return=11.0
# global_step=1965, episode=165, episode_return=9.0
# global_step=1979, episode=166, episode_return=13.0
# global_step=1990, episode=167, episode_return=10.0
# steps per second: 478
# global_step=2002, episode=168, episode_return=11.0
# global_step=2016, episode=169, episode_return=13.0
# global_step=2036, episode=170, episode_return=19.0
# global_step=2050, episode=171, episode_return=13.0
# global_step=2066, episode=172, episode_return=15.0
# global_step=2086, episode=173, episode_return=19.0
# global_step=2104, episode=174, episode_return=17.0
# global_step=2122, episode=175, episode_return=17.0
# global_step=2143, episode=176, episode_return=20.0
# global_step=2162, episode=177, episode_return=18.0
# global_step=2185, episode=178, episode_return=22.0
# global_step=2215, episode=179, episode_return=29.0
# global_step=2237, episode=180, episode_return=21.0
# global_step=2263, episode=181, episode_return=25.0
# global_step=2294, episode=182, episode_return=30.0
# global_step=2323, episode=183, episode_return=28.0
# global_step=2344, episode=184, episode_return=20.0
# global_step=2362, episode=185, episode_return=17.0
# global_step=2384, episode=186, episode_return=21.0
# global_step=2404, episode=187, episode_return=19.0
# global_step=2437, episode=188, episode_return=32.0
# global_step=2475, episode=189, episode_return=37.0
# global_step=2493, episode=190, episode_return=17.0
# global_step=2511, episode=191, episode_return=17.0
# global_step=2522, episode=192, episode_return=10.0
# global_step=2536, episode=193, episode_return=13.0
# global_step=2549, episode=194, episode_return=12.0
# global_step=2559, episode=195, episode_return=9.0
# global_step=2570, episode=196, episode_return=10.0
# global_step=2581, episode=197, episode_return=10.0
# global_step=2591, episode=198, episode_return=9.0
# global_step=2602, episode=199, episode_return=10.0
# global_step=2619, episode=200, episode_return=16.0
# global_step=2629, episode=201, episode_return=9.0
# global_step=2641, episode=202, episode_return=11.0
# global_step=2651, episode=203, episode_return=9.0
# global_step=2662, episode=204, episode_return=10.0
# global_step=2673, episode=205, episode_return=10.0
# global_step=2690, episode=206, episode_return=16.0
# global_step=2700, episode=207, episode_return=9.0
# global_step=2711, episode=208, episode_return=10.0
# global_step=2721, episode=209, episode_return=9.0
# global_step=2733, episode=210, episode_return=11.0
# global_step=2746, episode=211, episode_return=12.0
# global_step=2758, episode=212, episode_return=11.0
# global_step=2773, episode=213, episode_return=14.0
# global_step=2791, episode=214, episode_return=17.0
# global_step=2809, episode=215, episode_return=17.0
# global_step=2825, episode=216, episode_return=15.0
# global_step=2861, episode=217, episode_return=35.0
# steps per second: 530
# global_step=3004, episode=218, episode_return=142.0
# global_step=3020, episode=219, episode_return=15.0
# global_step=3030, episode=220, episode_return=9.0
# global_step=3041, episode=221, episode_return=10.0
# global_step=3053, episode=222, episode_return=11.0
# global_step=3063, episode=223, episode_return=9.0
# global_step=3078, episode=224, episode_return=14.0
# global_step=3091, episode=225, episode_return=12.0
# global_step=3102, episode=226, episode_return=10.0
# global_step=3112, episode=227, episode_return=9.0
# global_step=3126, episode=228, episode_return=13.0
# global_step=3139, episode=229, episode_return=12.0
# global_step=3150, episode=230, episode_return=10.0
# global_step=3161, episode=231, episode_return=10.0
# global_step=3171, episode=232, episode_return=9.0
# global_step=3182, episode=233, episode_return=10.0
# global_step=3192, episode=234, episode_return=9.0
# global_step=3203, episode=235, episode_return=10.0
# global_step=3214, episode=236, episode_return=10.0
# global_step=3225, episode=237, episode_return=10.0
# global_step=3234, episode=238, episode_return=8.0
# global_step=3247, episode=239, episode_return=12.0
# global_step=3258, episode=240, episode_return=10.0
# global_step=3272, episode=241, episode_return=13.0
# global_step=3283, episode=242, episode_return=10.0
# global_step=3296, episode=243, episode_return=12.0
# global_step=3307, episode=244, episode_return=10.0
# global_step=3320, episode=245, episode_return=12.0
# global_step=3336, episode=246, episode_return=15.0
# global_step=3349, episode=247, episode_return=12.0
# global_step=3365, episode=248, episode_return=15.0
# global_step=3386, episode=249, episode_return=20.0
# global_step=3407, episode=250, episode_return=20.0
# global_step=3428, episode=251, episode_return=20.0
# global_step=3451, episode=252, episode_return=22.0
# global_step=3474, episode=253, episode_return=22.0
# global_step=3507, episode=254, episode_return=32.0
# global_step=3546, episode=255, episode_return=38.0
# global_step=3592, episode=256, episode_return=45.0
# global_step=3662, episode=257, episode_return=69.0
# global_step=3803, episode=258, episode_return=140.0
# global_step=3827, episode=259, episode_return=23.0
# global_step=3849, episode=260, episode_return=21.0
# global_step=3874, episode=261, episode_return=24.0
# global_step=3890, episode=262, episode_return=15.0
# global_step=3903, episode=263, episode_return=12.0
# global_step=3915, episode=264, episode_return=11.0
# global_step=3927, episode=265, episode_return=11.0
# global_step=3940, episode=266, episode_return=12.0
# global_step=3952, episode=267, episode_return=11.0
# global_step=3970, episode=268, episode_return=17.0
# global_step=3984, episode=269, episode_return=13.0
# steps per second: 568
# global_step=4003, episode=270, episode_return=18.0
# global_step=4016, episode=271, episode_return=12.0
# global_step=4032, episode=272, episode_return=15.0
# global_step=4052, episode=273, episode_return=19.0
# global_step=4080, episode=274, episode_return=27.0
# global_step=4100, episode=275, episode_return=19.0
# global_step=4117, episode=276, episode_return=16.0
# global_step=4136, episode=277, episode_return=18.0
# global_step=4151, episode=278, episode_return=14.0
# global_step=4174, episode=279, episode_return=22.0
# global_step=4193, episode=280, episode_return=18.0
# global_step=4210, episode=281, episode_return=16.0
# global_step=4228, episode=282, episode_return=17.0
# global_step=4244, episode=283, episode_return=15.0
# global_step=4256, episode=284, episode_return=11.0
# global_step=4269, episode=285, episode_return=12.0
# global_step=4282, episode=286, episode_return=12.0
# global_step=4295, episode=287, episode_return=12.0
# global_step=4309, episode=288, episode_return=13.0
# global_step=4326, episode=289, episode_return=16.0
# global_step=4344, episode=290, episode_return=17.0
# global_step=4363, episode=291, episode_return=18.0
# global_step=4381, episode=292, episode_return=17.0
# global_step=4396, episode=293, episode_return=14.0
# global_step=4416, episode=294, episode_return=19.0
# global_step=4437, episode=295, episode_return=20.0
# global_step=4455, episode=296, episode_return=17.0
# global_step=4477, episode=297, episode_return=21.0
# global_step=4501, episode=298, episode_return=23.0
# global_step=4536, episode=299, episode_return=34.0
# global_step=4583, episode=300, episode_return=46.0
# global_step=4695, episode=301, episode_return=111.0
# global_step=4744, episode=302, episode_return=48.0
# global_step=4775, episode=303, episode_return=30.0
# global_step=4842, episode=304, episode_return=66.0
# global_step=4889, episode=305, episode_return=46.0
# global_step=4917, episode=306, episode_return=27.0
# global_step=4937, episode=307, episode_return=19.0
# global_step=4957, episode=308, episode_return=19.0
# global_step=4978, episode=309, episode_return=20.0
# global_step=4996, episode=310, episode_return=17.0
# steps per second: 592
# global_step=5014, episode=311, episode_return=17.0
# global_step=5030, episode=312, episode_return=15.0
# global_step=5049, episode=313, episode_return=18.0
# global_step=5071, episode=314, episode_return=21.0
# global_step=5104, episode=315, episode_return=32.0
# global_step=5123, episode=316, episode_return=18.0
# global_step=5142, episode=317, episode_return=18.0
# global_step=5156, episode=318, episode_return=13.0
# global_step=5173, episode=319, episode_return=16.0
# global_step=5191, episode=320, episode_return=17.0
# global_step=5213, episode=321, episode_return=21.0
# global_step=5238, episode=322, episode_return=24.0
# global_step=5266, episode=323, episode_return=27.0
# global_step=5290, episode=324, episode_return=23.0
# global_step=5323, episode=325, episode_return=32.0
# global_step=5358, episode=326, episode_return=34.0
# global_step=5423, episode=327, episode_return=64.0
# global_step=5492, episode=328, episode_return=68.0
# global_step=5559, episode=329, episode_return=66.0
# global_step=5590, episode=330, episode_return=30.0
# global_step=5639, episode=331, episode_return=48.0
# global_step=5711, episode=332, episode_return=71.0
# global_step=5756, episode=333, episode_return=44.0
# global_step=5788, episode=334, episode_return=31.0
# global_step=5814, episode=335, episode_return=25.0
# global_step=5838, episode=336, episode_return=23.0
# global_step=5862, episode=337, episode_return=23.0
# global_step=5880, episode=338, episode_return=17.0
# global_step=5907, episode=339, episode_return=26.0
# global_step=5930, episode=340, episode_return=22.0
# global_step=5964, episode=341, episode_return=33.0
# global_step=5990, episode=342, episode_return=25.0
# steps per second: 609
# global_step=6015, episode=343, episode_return=24.0
# global_step=6040, episode=344, episode_return=24.0
# global_step=6077, episode=345, episode_return=36.0
# global_step=6102, episode=346, episode_return=24.0
# global_step=6126, episode=347, episode_return=23.0
# global_step=6145, episode=348, episode_return=18.0
# global_step=6159, episode=349, episode_return=13.0
# global_step=6175, episode=350, episode_return=15.0
# global_step=6191, episode=351, episode_return=15.0
# global_step=6208, episode=352, episode_return=16.0
# global_step=6231, episode=353, episode_return=22.0
# global_step=6252, episode=354, episode_return=20.0
# global_step=6270, episode=355, episode_return=17.0
# global_step=6286, episode=356, episode_return=15.0
# global_step=6302, episode=357, episode_return=15.0
# global_step=6316, episode=358, episode_return=13.0
# global_step=6333, episode=359, episode_return=16.0
# global_step=6349, episode=360, episode_return=15.0
# global_step=6363, episode=361, episode_return=13.0
# global_step=6381, episode=362, episode_return=17.0
# global_step=6395, episode=363, episode_return=13.0
# global_step=6413, episode=364, episode_return=17.0
# global_step=6429, episode=365, episode_return=15.0
# global_step=6446, episode=366, episode_return=16.0
# global_step=6465, episode=367, episode_return=18.0
# global_step=6485, episode=368, episode_return=19.0
# global_step=6521, episode=369, episode_return=35.0
# global_step=6547, episode=370, episode_return=25.0
# global_step=6611, episode=371, episode_return=63.0
# global_step=6642, episode=372, episode_return=30.0
# global_step=6665, episode=373, episode_return=22.0
# global_step=6685, episode=374, episode_return=19.0
# global_step=6703, episode=375, episode_return=17.0
# global_step=6719, episode=376, episode_return=15.0
# global_step=6737, episode=377, episode_return=17.0
# global_step=6752, episode=378, episode_return=14.0
# global_step=6762, episode=379, episode_return=9.0
# global_step=6775, episode=380, episode_return=12.0
# global_step=6790, episode=381, episode_return=14.0
# global_step=6804, episode=382, episode_return=13.0
# global_step=6822, episode=383, episode_return=17.0
# global_step=6843, episode=384, episode_return=20.0
# global_step=6868, episode=385, episode_return=24.0
# steps per second: 610
# global_step=7002, episode=386, episode_return=133.0
# global_step=7045, episode=387, episode_return=42.0
# global_step=7096, episode=388, episode_return=50.0
# global_step=7142, episode=389, episode_return=45.0
# global_step=7174, episode=390, episode_return=31.0
# global_step=7207, episode=391, episode_return=32.0
# global_step=7234, episode=392, episode_return=26.0
# global_step=7253, episode=393, episode_return=18.0
# global_step=7281, episode=394, episode_return=27.0
# global_step=7307, episode=395, episode_return=25.0
# global_step=7338, episode=396, episode_return=30.0
# global_step=7372, episode=397, episode_return=33.0
# global_step=7417, episode=398, episode_return=44.0
# global_step=7558, episode=399, episode_return=140.0
# global_step=7598, episode=400, episode_return=39.0
# global_step=7631, episode=401, episode_return=32.0
# global_step=7659, episode=402, episode_return=27.0
# global_step=7679, episode=403, episode_return=19.0
# global_step=7696, episode=404, episode_return=16.0
# global_step=7710, episode=405, episode_return=13.0
# global_step=7725, episode=406, episode_return=14.0
# global_step=7736, episode=407, episode_return=10.0
# global_step=7748, episode=408, episode_return=11.0
# global_step=7762, episode=409, episode_return=13.0
# global_step=7774, episode=410, episode_return=11.0
# global_step=7786, episode=411, episode_return=11.0
# global_step=7797, episode=412, episode_return=10.0
# global_step=7813, episode=413, episode_return=15.0
# global_step=7833, episode=414, episode_return=19.0
# global_step=7868, episode=415, episode_return=34.0
# global_step=7945, episode=416, episode_return=76.0
# global_step=7971, episode=417, episode_return=25.0
# global_step=7987, episode=418, episode_return=15.0
# steps per second: 603
# global_step=8005, episode=419, episode_return=17.0
# global_step=8025, episode=420, episode_return=19.0
# global_step=8042, episode=421, episode_return=16.0
# global_step=8067, episode=422, episode_return=24.0
# global_step=8101, episode=423, episode_return=33.0
# global_step=8131, episode=424, episode_return=29.0
# global_step=11116, episode=495, episode_return=55.0
# global_step=11145, episode=496, episode_return=28.0
# global_step=11174, episode=497, episode_return=28.0
# global_step=11196, episode=498, episode_return=21.0
# global_step=11223, episode=499, episode_return=26.0
# global_step=11253, episode=500, episode_return=29.0
# global_step=11299, episode=501, episode_return=45.0
# global_step=11335, episode=502, episode_return=35.0
# global_step=11383, episode=503, episode_return=47.0
# global_step=11416, episode=504, episode_return=32.0
# global_step=11451, episode=505, episode_return=34.0
# global_step=11484, episode=506, episode_return=32.0
# global_step=11517, episode=507, episode_return=32.0
# global_step=11553, episode=508, episode_return=35.0
# global_step=11749, episode=509, episode_return=195.0
# global_step=11790, episode=510, episode_return=40.0
# global_step=11896, episode=511, episode_return=105.0
# global_step=11939, episode=512, episode_return=42.0
# global_step=11970, episode=513, episode_return=30.0
# global_step=11995, episode=514, episode_return=24.0
# steps per second: 637
# global_step=12026, episode=515, episode_return=30.0
# global_step=12067, episode=516, episode_return=40.0
# global_step=12104, episode=517, episode_return=36.0
# global_step=12137, episode=518, episode_return=32.0
# global_step=12169, episode=519, episode_return=31.0
# global_step=12207, episode=520, episode_return=37.0
# global_step=12307, episode=521, episode_return=99.0
# global_step=12434, episode=522, episode_return=126.0
# global_step=12453, episode=523, episode_return=18.0
# global_step=12482, episode=524, episode_return=28.0
# global_step=12524, episode=525, episode_return=41.0
# global_step=12564, episode=526, episode_return=39.0
# global_step=12596, episode=527, episode_return=31.0
# global_step=12625, episode=528, episode_return=28.0
# global_step=12645, episode=529, episode_return=19.0
# global_step=12673, episode=530, episode_return=27.0
# global_step=12695, episode=531, episode_return=21.0
# global_step=12721, episode=532, episode_return=25.0
# global_step=12755, episode=533, episode_return=33.0
# global_step=12798, episode=534, episode_return=42.0
# global_step=12858, episode=535, episode_return=59.0
# global_step=12961, episode=536, episode_return=102.0
# steps per second: 642
# global_step=13042, episode=537, episode_return=80.0
# global_step=13160, episode=538, episode_return=117.0
# global_step=13180, episode=539, episode_return=19.0
# global_step=13196, episode=540, episode_return=15.0
# global_step=13217, episode=541, episode_return=20.0
# global_step=13246, episode=542, episode_return=28.0
# global_step=13268, episode=543, episode_return=21.0
# global_step=13293, episode=544, episode_return=24.0
# global_step=13324, episode=545, episode_return=30.0
# global_step=13355, episode=546, episode_return=30.0
# global_step=13438, episode=547, episode_return=82.0
# global_step=13658, episode=548, episode_return=219.0
# global_step=13718, episode=549, episode_return=59.0
# global_step=13841, episode=550, episode_return=122.0
# global_step=13895, episode=551, episode_return=53.0
# global_step=13927, episode=552, episode_return=31.0
# global_step=13949, episode=553, episode_return=21.0
# global_step=13970, episode=554, episode_return=20.0
# global_step=13990, episode=555, episode_return=19.0
# steps per second: 646
# global_step=14143, episode=556, episode_return=152.0
# global_step=14279, episode=557, episode_return=135.0
# global_step=14313, episode=558, episode_return=33.0
# global_step=14474, episode=559, episode_return=160.0
# global_step=14509, episode=560, episode_return=34.0
# global_step=14631, episode=561, episode_return=121.0
# global_step=14804, episode=562, episode_return=172.0
# steps per second: 650
# global_step=15023, episode=563, episode_return=218.0
# global_step=15096, episode=564, episode_return=72.0
# global_step=15121, episode=565, episode_return=24.0
# global_step=15146, episode=566, episode_return=24.0
# global_step=15218, episode=567, episode_return=71.0
# global_step=15368, episode=568, episode_return=149.0
# global_step=15466, episode=569, episode_return=97.0
# global_step=15506, episode=570, episode_return=39.0
# global_step=15547, episode=571, episode_return=40.0
# global_step=15611, episode=572, episode_return=63.0
# global_step=15660, episode=573, episode_return=48.0
# global_step=15706, episode=574, episode_return=45.0
# global_step=15741, episode=575, episode_return=34.0
# steps per second: 641
# global_step=16212, episode=576, episode_return=470.0
# global_step=16241, episode=577, episode_return=28.0
# global_step=16495, episode=578, episode_return=253.0
# global_step=16545, episode=579, episode_return=49.0
# global_step=16588, episode=580, episode_return=42.0
# global_step=16628, episode=581, episode_return=39.0
# global_step=16653, episode=582, episode_return=24.0
# global_step=16725, episode=583, episode_return=71.0
# global_step=16806, episode=584, episode_return=80.0
# global_step=16886, episode=585, episode_return=79.0
# global_step=16967, episode=586, episode_return=80.0
# steps per second: 642
# global_step=17050, episode=587, episode_return=82.0
# global_step=17261, episode=588, episode_return=210.0
# global_step=17390, episode=589, episode_return=128.0
# global_step=17587, episode=590, episode_return=196.0
# global_step=17700, episode=591, episode_return=112.0
# global_step=17831, episode=592, episode_return=130.0
# global_step=17948, episode=593, episode_return=116.0
# steps per second: 646
# global_step=18107, episode=594, episode_return=158.0
# global_step=18244, episode=595, episode_return=136.0
# global_step=18424, episode=596, episode_return=179.0
# global_step=18623, episode=597, episode_return=198.0
# global_step=18864, episode=598, episode_return=240.0
# steps per second: 648
# global_step=19066, episode=599, episode_return=201.0
# global_step=19213, episode=600, episode_return=146.0
# global_step=19406, episode=601, episode_return=192.0
# global_step=19563, episode=602, episode_return=156.0
# global_step=19576, episode=603, episode_return=12.0
# global_step=19834, episode=604, episode_return=257.0
# steps per second: 651
# global_step=20005, episode=605, episode_return=170.0
# global_step=20021, episode=606, episode_return=15.0
# global_step=20522, episode=607, episode_return=500.0
# global_step=20668, episode=608, episode_return=145.0
# steps per second: 654
# global_step=21032, episode=609, episode_return=363.0
# global_step=21046, episode=610, episode_return=13.0
# global_step=21058, episode=611, episode_return=11.0
# global_step=21067, episode=612, episode_return=8.0
# global_step=21077, episode=613, episode_return=9.0
# global_step=21088, episode=614, episode_return=10.0
# global_step=21099, episode=615, episode_return=10.0
# global_step=21111, episode=616, episode_return=11.0
# global_step=21124, episode=617, episode_return=12.0
# global_step=21136, episode=618, episode_return=11.0
# global_step=21150, episode=619, episode_return=13.0
# global_step=21164, episode=620, episode_return=13.0
# global_step=21181, episode=621, episode_return=16.0
# global_step=21202, episode=622, episode_return=20.0
# global_step=21433, episode=623, episode_return=230.0
# global_step=21443, episode=624, episode_return=9.0
# global_step=21454, episode=625, episode_return=10.0
# global_step=21464, episode=626, episode_return=9.0
# global_step=21474, episode=627, episode_return=9.0
# global_step=21487, episode=628, episode_return=12.0
# global_step=21497, episode=629, episode_return=9.0
# global_step=21507, episode=630, episode_return=9.0
# global_step=21518, episode=631, episode_return=10.0
# global_step=21530, episode=632, episode_return=11.0
# global_step=21541, episode=633, episode_return=10.0
# global_step=21551, episode=634, episode_return=9.0
# global_step=21562, episode=635, episode_return=10.0
# global_step=21574, episode=636, episode_return=11.0
# global_step=21586, episode=637, episode_return=11.0
# global_step=21596, episode=638, episode_return=9.0
# global_step=21608, episode=639, episode_return=11.0
# global_step=21621, episode=640, episode_return=12.0
# global_step=21634, episode=641, episode_return=12.0
# global_step=21646, episode=642, episode_return=11.0
# global_step=21658, episode=643, episode_return=11.0
# global_step=21671, episode=644, episode_return=12.0
# global_step=21684, episode=645, episode_return=12.0
# global_step=21699, episode=646, episode_return=14.0
# global_step=21712, episode=647, episode_return=12.0
# global_step=21733, episode=648, episode_return=20.0
# global_step=21753, episode=649, episode_return=19.0
# global_step=21858, episode=650, episode_return=104.0
# steps per second: 657
# global_step=22114, episode=651, episode_return=255.0
# global_step=22237, episode=652, episode_return=122.0
# global_step=22419, episode=653, episode_return=181.0
# global_step=22590, episode=654, episode_return=170.0
# global_step=22787, episode=655, episode_return=196.0
# global_step=22913, episode=656, episode_return=125.0
# global_step=22946, episode=657, episode_return=32.0
# steps per second: 658
# global_step=23060, episode=658, episode_return=113.0
# global_step=23165, episode=659, episode_return=104.0
# global_step=23186, episode=660, episode_return=20.0
# global_step=23208, episode=661, episode_return=21.0
# global_step=23238, episode=662, episode_return=29.0
# global_step=23279, episode=663, episode_return=40.0
# global_step=23308, episode=664, episode_return=28.0
# global_step=23337, episode=665, episode_return=28.0
# global_step=23446, episode=666, episode_return=108.0
# global_step=23557, episode=667, episode_return=110.0
# global_step=23731, episode=668, episode_return=173.0
# global_step=23888, episode=669, episode_return=156.0
# steps per second: 653
# global_step=24077, episode=670, episode_return=188.0
# global_step=24202, episode=671, episode_return=124.0
# global_step=24313, episode=672, episode_return=110.0
# global_step=24424, episode=673, episode_return=110.0
# global_step=24561, episode=674, episode_return=136.0
# global_step=24726, episode=675, episode_return=164.0
# global_step=24904, episode=676, episode_return=177.0
# steps per second: 650
# global_step=25017, episode=677, episode_return=112.0
# global_step=25162, episode=678, episode_return=144.0
# global_step=25334, episode=679, episode_return=171.0
# global_step=25502, episode=680, episode_return=167.0
# global_step=25645, episode=681, episode_return=142.0
# global_step=25774, episode=682, episode_return=128.0
# global_step=25906, episode=683, episode_return=131.0
# global_step=25927, episode=684, episode_return=20.0
# global_step=25945, episode=685, episode_return=17.0
# global_step=25959, episode=686, episode_return=13.0
# global_step=25975, episode=687, episode_return=15.0
# global_step=26000, episode=688, episode_return=24.0
# steps per second: 652
# global_step=26106, episode=689, episode_return=105.0
# global_step=26287, episode=690, episode_return=180.0
# global_step=26518, episode=691, episode_return=230.0
# global_step=26860, episode=692, episode_return=341.0
# steps per second: 654
# global_step=27042, episode=693, episode_return=181.0
# global_step=27225, episode=694, episode_return=182.0
# global_step=27414, episode=695, episode_return=188.0
# global_step=27602, episode=696, episode_return=187.0
# global_step=27789, episode=697, episode_return=186.0
# global_step=27918, episode=698, episode_return=128.0
# steps per second: 655
# global_step=28183, episode=699, episode_return=264.0
# global_step=28374, episode=700, episode_return=190.0
# global_step=28598, episode=701, episode_return=223.0
# global_step=28789, episode=702, episode_return=190.0
# global_step=28916, episode=703, episode_return=126.0
# steps per second: 657
# global_step=29056, episode=704, episode_return=139.0
# global_step=29200, episode=705, episode_return=143.0
# global_step=29357, episode=706, episode_return=156.0
# global_step=29511, episode=707, episode_return=153.0
# global_step=29529, episode=708, episode_return=17.0
# global_step=29546, episode=709, episode_return=16.0
# global_step=29566, episode=710, episode_return=19.0
# global_step=29587, episode=711, episode_return=20.0
# global_step=29717, episode=712, episode_return=129.0
# steps per second: 659
# global_step=30218, episode=713, episode_return=500.0
# global_step=30446, episode=714, episode_return=227.0
# global_step=30582, episode=715, episode_return=135.0
# steps per second: 660
# global_step=31083, episode=716, episode_return=500.0
# global_step=31307, episode=717, episode_return=223.0
# global_step=31433, episode=718, episode_return=125.0
# global_step=31909, episode=719, episode_return=475.0
# steps per second: 659
# global_step=32061, episode=720, episode_return=151.0
# global_step=32410, episode=721, episode_return=348.0
# global_step=32711, episode=722, episode_return=300.0
# global_step=32735, episode=723, episode_return=23.0
# global_step=32756, episode=724, episode_return=20.0
# global_step=32775, episode=725, episode_return=18.0
# global_step=32930, episode=726, episode_return=154.0
# steps per second: 655
# global_step=33352, episode=727, episode_return=421.0
# global_step=33570, episode=728, episode_return=217.0
# global_step=33802, episode=729, episode_return=231.0
# steps per second: 657
# global_step=34057, episode=730, episode_return=254.0
# global_step=34276, episode=731, episode_return=218.0
# global_step=34777, episode=732, episode_return=500.0
# steps per second: 658
# global_step=35038, episode=733, episode_return=260.0
# global_step=35284, episode=734, episode_return=245.0
# global_step=35461, episode=735, episode_return=176.0
# global_step=35477, episode=736, episode_return=15.0
# global_step=35489, episode=737, episode_return=11.0
# global_step=35504, episode=738, episode_return=14.0
# global_step=35521, episode=739, episode_return=16.0
# global_step=35534, episode=740, episode_return=12.0
# global_step=35549, episode=741, episode_return=14.0
# global_step=35566, episode=742, episode_return=16.0
# global_step=35720, episode=743, episode_return=153.0
# global_step=35878, episode=744, episode_return=157.0
# global_step=35893, episode=745, episode_return=14.0
# global_step=35907, episode=746, episode_return=13.0
# global_step=35919, episode=747, episode_return=11.0
# global_step=35930, episode=748, episode_return=10.0
# global_step=35943, episode=749, episode_return=12.0
# global_step=35954, episode=750, episode_return=10.0
# global_step=35964, episode=751, episode_return=9.0
# global_step=35976, episode=752, episode_return=11.0
# global_step=35990, episode=753, episode_return=13.0
# steps per second: 660
# global_step=36004, episode=754, episode_return=13.0
# global_step=36017, episode=755, episode_return=12.0
# global_step=36034, episode=756, episode_return=16.0
# global_step=36054, episode=757, episode_return=19.0
# global_step=36076, episode=758, episode_return=21.0
# global_step=36191, episode=759, episode_return=114.0
# global_step=36406, episode=760, episode_return=214.0
# global_step=36519, episode=761, episode_return=112.0
# global_step=36633, episode=762, episode_return=113.0
# global_step=36737, episode=763, episode_return=103.0
# global_step=36821, episode=764, episode_return=83.0
# global_step=36914, episode=765, episode_return=92.0
# steps per second: 661
# global_step=37008, episode=766, episode_return=93.0
# global_step=37079, episode=767, episode_return=70.0
# global_step=37177, episode=768, episode_return=97.0
# global_step=37285, episode=769, episode_return=107.0
# global_step=37389, episode=770, episode_return=103.0
# global_step=37491, episode=771, episode_return=101.0
# global_step=37569, episode=772, episode_return=77.0
# global_step=37658, episode=773, episode_return=88.0
# global_step=37723, episode=774, episode_return=64.0
# global_step=37802, episode=775, episode_return=78.0
# global_step=37895, episode=776, episode_return=92.0
# global_step=37990, episode=777, episode_return=94.0
# steps per second: 663
# global_step=38075, episode=778, episode_return=84.0
# global_step=38151, episode=779, episode_return=75.0
# global_step=38235, episode=780, episode_return=83.0
# global_step=38314, episode=781, episode_return=78.0
# global_step=38411, episode=782, episode_return=96.0
# global_step=38497, episode=783, episode_return=85.0
# global_step=38561, episode=784, episode_return=63.0
# global_step=38640, episode=785, episode_return=78.0
# global_step=38712, episode=786, episode_return=71.0
# global_step=38780, episode=787, episode_return=67.0
# global_step=38834, episode=788, episode_return=53.0
# global_step=38897, episode=789, episode_return=62.0
# global_step=38976, episode=790, episode_return=78.0
# steps per second: 664
# global_step=39049, episode=791, episode_return=72.0
# global_step=39121, episode=792, episode_return=71.0
# global_step=39198, episode=793, episode_return=76.0
# global_step=39283, episode=794, episode_return=84.0
# global_step=39358, episode=795, episode_return=74.0
# global_step=39429, episode=796, episode_return=70.0
# global_step=39503, episode=797, episode_return=73.0
# global_step=39569, episode=798, episode_return=65.0
# global_step=39641, episode=799, episode_return=71.0
# global_step=39706, episode=800, episode_return=64.0
# global_step=39773, episode=801, episode_return=66.0
# global_step=39857, episode=802, episode_return=83.0
# global_step=39934, episode=803, episode_return=76.0
# global_step=40000, episode=804, episode_return=65.0
# steps per second: 664
# global_step=40085, episode=805, episode_return=84.0
# global_step=40168, episode=806, episode_return=82.0
# global_step=40230, episode=807, episode_return=61.0
# global_step=40294, episode=808, episode_return=63.0
# global_step=40358, episode=809, episode_return=63.0
# global_step=40425, episode=810, episode_return=66.0
# global_step=40488, episode=811, episode_return=62.0
# global_step=40546, episode=812, episode_return=57.0
# global_step=40601, episode=813, episode_return=54.0
# global_step=40673, episode=814, episode_return=71.0
# global_step=40750, episode=815, episode_return=76.0
# global_step=40811, episode=816, episode_return=60.0
# global_step=40861, episode=817, episode_return=49.0
# global_step=40910, episode=818, episode_return=48.0
# global_step=40947, episode=819, episode_return=36.0
# global_step=40996, episode=820, episode_return=48.0
# steps per second: 659
# global_step=41063, episode=821, episode_return=66.0
# global_step=41151, episode=822, episode_return=87.0
# global_step=41191, episode=823, episode_return=39.0
# global_step=41219, episode=824, episode_return=27.0
# global_step=41242, episode=825, episode_return=22.0
# global_step=41266, episode=826, episode_return=23.0
# global_step=41305, episode=827, episode_return=38.0
# global_step=41376, episode=828, episode_return=70.0
# global_step=41440, episode=829, episode_return=63.0
# global_step=41511, episode=830, episode_return=70.0
# global_step=41597, episode=831, episode_return=85.0
# global_step=41667, episode=832, episode_return=69.0
# global_step=41743, episode=833, episode_return=75.0
# global_step=41836, episode=834, episode_return=92.0
# global_step=41899, episode=835, episode_return=62.0
# global_step=41962, episode=836, episode_return=62.0
# steps per second: 660
# global_step=42019, episode=837, episode_return=56.0
# global_step=42077, episode=838, episode_return=57.0
# global_step=42167, episode=839, episode_return=89.0
# global_step=42248, episode=840, episode_return=80.0
# global_step=42322, episode=841, episode_return=73.0
# global_step=42394, episode=842, episode_return=71.0
# global_step=42468, episode=843, episode_return=73.0
# global_step=42546, episode=844, episode_return=77.0
# global_step=42594, episode=845, episode_return=47.0
# global_step=42669, episode=846, episode_return=74.0
# global_step=42762, episode=847, episode_return=92.0
# global_step=42845, episode=848, episode_return=82.0
# global_step=42925, episode=849, episode_return=79.0
# steps per second: 661
# global_step=43017, episode=850, episode_return=91.0
# global_step=43117, episode=851, episode_return=99.0
# global_step=43229, episode=852, episode_return=111.0
# global_step=43356, episode=853, episode_return=126.0
# global_step=43491, episode=854, episode_return=134.0
# global_step=43598, episode=855, episode_return=106.0
# global_step=43735, episode=856, episode_return=136.0
# global_step=43857, episode=857, episode_return=121.0
# global_step=44000, episode=858, episode_return=142.0
# steps per second: 662
# global_step=44182, episode=859, episode_return=181.0
# global_step=44455, episode=860, episode_return=272.0
# global_step=44706, episode=861, episode_return=250.0
# global_step=44986, episode=862, episode_return=279.0
# steps per second: 663
# global_step=45255, episode=863, episode_return=268.0
# global_step=45505, episode=864, episode_return=249.0
# global_step=45807, episode=865, episode_return=301.0
# steps per second: 664
# global_step=46228, episode=866, episode_return=420.0
# global_step=46653, episode=867, episode_return=424.0
# steps per second: 665
# global_step=47154, episode=868, episode_return=500.0
# global_step=47348, episode=869, episode_return=193.0
# global_step=47467, episode=870, episode_return=118.0
# global_step=47730, episode=871, episode_return=262.0
# global_step=47850, episode=872, episode_return=119.0
# global_step=47981, episode=873, episode_return=130.0
# steps per second: 665
# global_step=48093, episode=874, episode_return=111.0
# global_step=48211, episode=875, episode_return=117.0
# global_step=48324, episode=876, episode_return=112.0
# global_step=48473, episode=877, episode_return=148.0
# global_step=48974, episode=878, episode_return=500.0
# steps per second: 662
# global_step=49115, episode=879, episode_return=140.0
# global_step=49289, episode=880, episode_return=173.0
# global_step=49399, episode=881, episode_return=109.0
# global_step=49530, episode=882, episode_return=130.0
# global_step=49633, episode=883, episode_return=102.0
# global_step=49744, episode=884, episode_return=110.0
# global_step=49864, episode=885, episode_return=119.0
# global_step=49884, episode=886, episode_return=19.0
# global_step=49904, episode=887, episode_return=19.0
# global_step=49918, episode=888, episode_return=13.0
# global_step=49935, episode=889, episode_return=16.0
# global_step=49950, episode=890, episode_return=14.0
# global_step=49975, episode=891, episode_return=24.0
# global_step=49993, episode=892, episode_return=17.0
# steps per second: 657
# global_step=50118, episode=893, episode_return=124.0
# global_step=50258, episode=894, episode_return=139.0
# global_step=50465, episode=895, episode_return=206.0
# global_step=50796, episode=896, episode_return=330.0
# steps per second: 656
# global_step=51131, episode=897, episode_return=334.0
# global_step=51361, episode=898, episode_return=229.0
# global_step=51620, episode=899, episode_return=258.0
# steps per second: 657
# global_step=52121, episode=900, episode_return=500.0
# global_step=52622, episode=901, episode_return=500.0
# steps per second: 657
# global_step=53039, episode=902, episode_return=416.0
# global_step=53274, episode=903, episode_return=234.0
# global_step=53591, episode=904, episode_return=316.0
# global_step=53858, episode=905, episode_return=266.0
# global_step=53971, episode=906, episode_return=112.0
# global_step=53983, episode=907, episode_return=11.0
# global_step=53997, episode=908, episode_return=13.0
# steps per second: 658
# global_step=54010, episode=909, episode_return=12.0
# global_step=54026, episode=910, episode_return=15.0
# global_step=54040, episode=911, episode_return=13.0
# ...
# steps per second: 658
# global_step=59093, episode=952, episode_return=243.0
# global_step=59372, episode=953, episode_return=278.0
# global_step=59633, episode=954, episode_return=260.0
# global_step=59999, episode=955, episode_return=365.0
# steps per second: 658
# global_step=60193, episode=956, episode_return=193.0
# global_step=60505, episode=957, episode_return=311.0
# global_step=60699, episode=958, episode_return=193.0
# global_step=60959, episode=959, episode_return=259.0
# steps per second: 659
# global_step=61113, episode=960, episode_return=153.0
# global_step=61266, episode=961, episode_return=152.0
# global_step=61478, episode=962, episode_return=211.0
# global_step=61637, episode=963, episode_return=158.0
# steps per second: 659
# global_step=62047, episode=964, episode_return=409.0
# global_step=62367, episode=965, episode_return=319.0
# global_step=62543, episode=966, episode_return=175.0
# global_step=62886, episode=967, episode_return=342.0
# steps per second: 660
# global_step=63074, episode=968, episode_return=187.0
# global_step=63322, episode=969, episode_return=247.0
# global_step=63555, episode=970, episode_return=232.0
# global_step=63698, episode=971, episode_return=142.0
# global_step=63898, episode=972, episode_return=199.0
# steps per second: 661
# global_step=64061, episode=973, episode_return=162.0
# global_step=64205, episode=974, episode_return=143.0
# global_step=64341, episode=975, episode_return=135.0
# global_step=64499, episode=976, episode_return=157.0
# global_step=64740, episode=977, episode_return=240.0
# steps per second: 658
# global_step=65139, episode=978, episode_return=398.0
# global_step=65355, episode=979, episode_return=215.0
# global_step=65618, episode=980, episode_return=262.0
# global_step=65853, episode=981, episode_return=234.0
# steps per second: 658
# global_step=66024, episode=982, episode_return=170.0
# global_step=66231, episode=983, episode_return=206.0
# global_step=66353, episode=984, episode_return=121.0
# global_step=66558, episode=985, episode_return=204.0
# global_step=66756, episode=986, episode_return=197.0
# global_step=66994, episode=987, episode_return=237.0
# steps per second: 658
# global_step=67282, episode=988, episode_return=287.0
# global_step=67429, episode=989, episode_return=146.0
# global_step=67532, episode=990, episode_return=102.0
# global_step=67687, episode=991, episode_return=154.0
# global_step=67873, episode=992, episode_return=185.0
# steps per second: 659
# global_step=68071, episode=993, episode_return=197.0
# global_step=68267, episode=994, episode_return=195.0
# global_step=68400, episode=995, episode_return=132.0
# global_step=68538, episode=996, episode_return=137.0
# global_step=68690, episode=997, episode_return=151.0
# global_step=68850, episode=998, episode_return=159.0
# steps per second: 660
# global_step=69066, episode=999, episode_return=215.0
# global_step=69218, episode=1000, episode_return=151.0
# global_step=69424, episode=1001, episode_return=205.0
# global_step=69620, episode=1002, episode_return=195.0
# global_step=69742, episode=1003, episode_return=121.0
# global_step=69876, episode=1004, episode_return=133.0
# steps per second: 660
# global_step=70034, episode=1005, episode_return=157.0
# global_step=70162, episode=1006, episode_return=127.0
# global_step=70306, episode=1007, episode_return=143.0
# global_step=70441, episode=1008, episode_return=134.0
# global_step=70580, episode=1009, episode_return=138.0
# global_step=70720, episode=1010, episode_return=139.0
# global_step=70851, episode=1011, episode_return=130.0
# global_step=70970, episode=1012, episode_return=118.0
# global_step=92373, episode=1209, episode_return=79.0
# global_step=92476, episode=1210, episode_return=102.0
# global_step=92583, episode=1211, episode_return=106.0
# global_step=92718, episode=1212, episode_return=134.0
# global_step=92786, episode=1213, episode_return=67.0
# global_step=92888, episode=1214, episode_return=101.0
# steps per second: 661
# global_step=93091, episode=1215, episode_return=202.0
# global_step=93307, episode=1216, episode_return=215.0
# global_step=93410, episode=1217, episode_return=102.0
# global_step=93545, episode=1218, episode_return=134.0
# global_step=93859, episode=1219, episode_return=313.0
# steps per second: 661
# global_step=94104, episode=1220, episode_return=244.0
# global_step=94605, episode=1221, episode_return=500.0
# global_step=94799, episode=1222, episode_return=193.0
# steps per second: 662
# global_step=95300, episode=1223, episode_return=500.0
# global_step=95774, episode=1224, episode_return=473.0
# steps per second: 662
# global_step=96275, episode=1225, episode_return=500.0
# global_step=96607, episode=1226, episode_return=331.0
# global_step=96819, episode=1227, episode_return=211.0
# steps per second: 662
# global_step=97146, episode=1228, episode_return=326.0
# global_step=97647, episode=1229, episode_return=500.0
# steps per second: 660
# global_step=98148, episode=1230, episode_return=500.0
# global_step=98649, episode=1231, episode_return=500.0
# steps per second: 661
# global_step=99150, episode=1232, episode_return=500.0
# global_step=99651, episode=1233, episode_return=500.0

# %%
# close env
envs.close()

# %%
def smooth(x, a=0.1):
    y = [x[0]]
    for xi in x[1:]:
        yi = a * xi + (1 - a) * y[-1]
        y.append(yi)
    return y

# %%
plt.plot(episode_returns, alpha=0.2)
plt.plot(smooth(episode_returns))
plt.title("episode_returns");
plt.show();

# %%
plt.plot(losses)
plt.title("losses");
plt.show();

# %%
# save model
model_path = "q_network.pth"
torch.save(q_network.state_dict(), model_path)

# %%
# load model for eval
envs_eval = gym.vector.SyncVectorEnv([lambda: make_env(env_id, True)])
model = QNetwork(envs_eval).to(device)
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()
# Out:
# QNetwork(
#   (network): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
# )

# %%
# evaluate the model
n_episodes_eval = 10
eval_returns = np.zeros(n_episodes_eval)
obs, _ = envs_eval.reset()
for i in range(n_episodes_eval):
  episode_done = False
  while not episode_done:
    q_values = model(np2torch(obs))
    actions = torch.argmax(q_values, dim=1).cpu().numpy()
    obs, rewards, dones, truncateds, infos = envs_eval.step(actions)
    if dones[0] or truncateds[0]:
      G = infos['episode']['r'][0]
      print(f"episode={i}, return={G}")
      eval_returns[i] = G
      episode_done = True

# close env
envs_eval.close()
# Out:
# episode=0, return=461.0
# episode=1, return=500.0
# episode=2, return=416.0
# episode=3, return=500.0
# episode=4, return=500.0
# episode=5, return=416.0
# episode=6, return=500.0
# episode=7, return=440.0
# episode=8, return=500.0
# episode=9, return=358.0

# %%
# plot the eval returns distribution
plt.hist(eval_returns)
plt.title("Eval Returns")
plt.show();

# %%
# prompt: display video in colab notebook with filename "videos/rl-video-episode-0.mp4"

from IPython.display import HTML
from base64 import b64encode

mp4 = open(f'{video_path}/rl-video-episode-0.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %% [markdown]
# ![](https://deeplearningcourses.com/notebooks_v3_pxl?sc=83SBIReT_VK9g4jXKsbP_w&n=Q+Learning)
