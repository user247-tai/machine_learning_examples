# %%
import random
import time

import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# settings
env_id  = "CartPole-v1"

# number of environments to run in parallel
num_envs = 1

# total number of timesteps for training over multiple episodes
total_timesteps = 100_000

# adam learning rate
learning_rate = 2e-3

# number of transitions to store in replay buffer
buffer_size = 10_000

# discount factor
gamma = 0.99

# target network update constant
# θ_target = 𝜏 * θ + (1 - 𝜏) * θ_target
tau = 1.0

# number of timesteps between target network updates
target_network_frequency = 50

# size of sample from replay buffer
batch_size = 32

# initial value of epsilon (100% exploration)
start_eps = 1

# final value of epsilon (1% exploration)
end_eps = 0.01

# number of steps to decrease from start_eps to end_eps
exploration_duration = int(0.1 * total_timesteps)

# number of steps before beginning training
num_steps_before_training = 5_000

# number of steps between each gradient descent step
train_frequency = 4

# optional: set seed for reproducibility
# seed = 123
seed = None

video_path = "dqn_cartpole_videos"

# %%
# will encapsulate in lambda later
def make_env(env_id, capture_video, seed=None):
    if capture_video:
        env = gym.make(env_id, render_mode="rgb_array")
        env = gym.wrappers.RecordVideo(env, video_path,
            episode_trigger=lambda episode: True)
        # ensure it records all episodes, by default it only records every 1000th
    else:
        env = gym.make(env_id)
    env = gym.wrappers.RecordEpisodeStatistics(env)

    # To get reproducible sampling of actions, a seed can be set with env.action_space.seed(123)
    if seed is not None:
        env.action_space.seed(seed)
    return env

# %%
class QNetwork(nn.Module):
    def __init__(self, envs, n_hidden=128):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(envs.single_observation_space.shape[0], n_hidden),
            nn.ReLU(),
            nn.Linear(n_hidden, envs.single_action_space.n),
        )

    def forward(self, x):
        return self.network(x)

# %%
def linear_schedule(start_eps, end_eps, duration, t):
    slope = (end_eps - start_eps) / duration
    return max(slope * t + start_eps, end_eps)

# %%
envs = gym.vector.SyncVectorEnv([
    lambda: make_env(
        env_id, False,
        seed if seed is None else seed + i) for i in range(num_envs)
])

# %%
# set device
device = torch.device(
    "cuda" if torch.cuda.is_available() else
    # "mps" if torch.backends.mps.is_available() else
    "cpu"
)

# %%
# make neural networks
q_network = QNetwork(envs).to(device)
optimizer = optim.Adam(q_network.parameters(), lr=learning_rate)
target_network = QNetwork(envs).to(device)
target_network.load_state_dict(q_network.state_dict()) # copy main to target
# Out:
# <All keys matched successfully>

# %%
class ReplayBuffer:
    def __init__(self, obs_dim, size):
        self.obs1_buf = np.zeros([size, obs_dim], dtype=np.float32)
        self.obs2_buf = np.zeros([size, obs_dim], dtype=np.float32)
        self.acts_buf = np.zeros(size, dtype=np.uint8)
        self.rews_buf = np.zeros(size, dtype=np.float32)
        self.done_buf = np.zeros(size, dtype=np.uint8)
        self.ptr, self.size, self.max_size = 0, 0, size

    def store(self, obs, act, rew, next_obs, done):
        self.obs1_buf[self.ptr] = obs
        self.obs2_buf[self.ptr] = next_obs
        self.acts_buf[self.ptr] = act
        self.rews_buf[self.ptr] = rew
        self.done_buf[self.ptr] = done
        self.ptr = (self.ptr+1) % self.max_size
        self.size = min(self.size+1, self.max_size)

    def sample_batch(self, batch_size=32):
        idxs = np.random.randint(0, self.size, size=batch_size)
        return dict(s=self.obs1_buf[idxs],
                    s2=self.obs2_buf[idxs],
                    a=self.acts_buf[idxs],
                    r=self.rews_buf[idxs],
                    d=self.done_buf[idxs])

# %%
rb = ReplayBuffer(
    envs.single_observation_space.shape[0],
    buffer_size,
)

# %%
def np2torch(a, to_float=True):
  if to_float:
    dtype = torch.float32
  else:
    dtype = torch.int64
  return torch.as_tensor(a, dtype=dtype, device=device)

# %%
# training loop

episode_returns = []
losses = []

start_time = time.time()
obs, _ = envs.reset(seed=seed)
autoreset = np.zeros(num_envs, dtype=bool)

for global_step in range(total_timesteps):

  # select an action based on epsilon-greedy
  epsilon = linear_schedule(start_eps, end_eps, exploration_duration, global_step)
  if random.random() < epsilon:
    actions = np.array([envs.single_action_space.sample() for _ in range(num_envs)])
  else:
    q_values = q_network(np2torch(obs))
    actions = torch.argmax(q_values, dim=1).cpu().numpy()

  # take a step in the environment
  next_obs, rewards, dones, truncateds, infos = envs.step(actions)

  # record returns for plotting
  for i, (done, truncated) in enumerate(zip(dones, truncateds)):
    if done or truncated:
      ret = infos["episode"]["r"][i]
      episode_returns.append(ret)
      print(f"global_step={global_step}, episode={len(episode_returns)}, episode_return={ret}")

  # update the replay buffer
  for i in range(num_envs):
    if not autoreset[i]:
      rb.store(obs[i], actions[i], rewards[i], next_obs[i], dones[i])

  # don't forget
  obs = next_obs

  # update autoreset
  autoreset = np.logical_or(dones, truncateds)

  # training
  if global_step > num_steps_before_training:
    if global_step % train_frequency == 0:
      batch = rb.sample_batch(batch_size)
      with torch.no_grad():
        target_max, _ = target_network(np2torch(batch["s2"])).max(dim=1)
        td_target = np2torch(batch["r"].flatten()) + \
        gamma * target_max * np2torch(1 - batch["d"].flatten())

      a = np2torch(batch['a'], to_float=False)
      a = a.reshape(-1, 1)
      s = np2torch(batch['s'])
      qsa = q_network(s)
      # want: Q(s, a) where a is the action done
      # np syntax: Qs[:, a]
      pred = qsa.gather(1, a).squeeze()
      loss = F.mse_loss(pred, td_target)
      losses.append(loss.item())

      # optimize the model
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

    if global_step % 1000 == 0:
      print("steps per second:", int(global_step / (time.time() - start_time)))

    # update the target network
    if global_step % target_network_frequency == 0:
      for target_network_param, q_network_param in zip(target_network.parameters(), q_network.parameters()):
        target_network_param.data.copy_(
            tau * q_network_param.data + (1.0 - tau) * target_network_param.data
        )

    # let's just break if the last 10 episodes had max reward
    if len(episode_returns) > 10 and np.all(np.equal(episode_returns[-10:], 500)):
        print("max reward achieved")
        break
# Out:
# global_step=26, episode=1, episode_return=27.0
# global_step=41, episode=2, episode_return=14.0
# global_step=60, episode=3, episode_return=18.0
# global_step=82, episode=4, episode_return=21.0
# global_step=121, episode=5, episode_return=38.0
# global_step=134, episode=6, episode_return=12.0
# global_step=175, episode=7, episode_return=40.0
# global_step=187, episode=8, episode_return=11.0
# global_step=222, episode=9, episode_return=34.0
# global_step=233, episode=10, episode_return=10.0
# global_step=249, episode=11, episode_return=15.0
# global_step=268, episode=12, episode_return=18.0
# global_step=304, episode=13, episode_return=35.0
# global_step=320, episode=14, episode_return=15.0
# global_step=347, episode=15, episode_return=26.0
# global_step=360, episode=16, episode_return=12.0
# global_step=374, episode=17, episode_return=13.0
# global_step=391, episode=18, episode_return=16.0
# global_step=408, episode=19, episode_return=16.0
# global_step=424, episode=20, episode_return=15.0
# global_step=457, episode=21, episode_return=32.0
# global_step=466, episode=22, episode_return=8.0
# global_step=492, episode=23, episode_return=25.0
# global_step=513, episode=24, episode_return=20.0
# global_step=538, episode=25, episode_return=24.0
# global_step=547, episode=26, episode_return=8.0
# global_step=562, episode=27, episode_return=14.0
# global_step=578, episode=28, episode_return=15.0
# global_step=600, episode=29, episode_return=21.0
# global_step=621, episode=30, episode_return=20.0
# global_step=637, episode=31, episode_return=15.0
# global_step=676, episode=32, episode_return=38.0
# global_step=696, episode=33, episode_return=19.0
# global_step=709, episode=34, episode_return=12.0
# global_step=739, episode=35, episode_return=29.0
# global_step=761, episode=36, episode_return=21.0
# global_step=779, episode=37, episode_return=17.0
# global_step=803, episode=38, episode_return=23.0
# global_step=844, episode=39, episode_return=40.0
# global_step=861, episode=40, episode_return=16.0
# global_step=878, episode=41, episode_return=16.0
# global_step=914, episode=42, episode_return=35.0
# global_step=953, episode=43, episode_return=38.0
# global_step=969, episode=44, episode_return=15.0
# global_step=991, episode=45, episode_return=21.0
# global_step=1038, episode=46, episode_return=46.0
# global_step=1074, episode=47, episode_return=35.0
# global_step=1101, episode=48, episode_return=26.0
# global_step=1120, episode=49, episode_return=18.0
# global_step=1132, episode=50, episode_return=11.0
# global_step=1150, episode=51, episode_return=17.0
# global_step=1172, episode=52, episode_return=21.0
# global_step=1203, episode=53, episode_return=30.0
# global_step=1230, episode=54, episode_return=26.0
# global_step=1244, episode=55, episode_return=13.0
# global_step=1257, episode=56, episode_return=12.0
# global_step=1272, episode=57, episode_return=14.0
# global_step=1283, episode=58, episode_return=10.0
# global_step=1306, episode=59, episode_return=22.0
# global_step=1322, episode=60, episode_return=15.0
# global_step=1343, episode=61, episode_return=20.0
# global_step=1362, episode=62, episode_return=18.0
# global_step=1382, episode=63, episode_return=19.0
# global_step=1393, episode=64, episode_return=10.0
# global_step=1405, episode=65, episode_return=11.0
# global_step=1419, episode=66, episode_return=13.0
# global_step=1445, episode=67, episode_return=25.0
# global_step=1462, episode=68, episode_return=16.0
# global_step=1482, episode=69, episode_return=19.0
# global_step=1495, episode=70, episode_return=12.0
# global_step=1513, episode=71, episode_return=17.0
# global_step=1541, episode=72, episode_return=27.0
# global_step=1579, episode=73, episode_return=37.0
# global_step=1600, episode=74, episode_return=20.0
# global_step=1623, episode=75, episode_return=22.0
# global_step=1633, episode=76, episode_return=9.0
# global_step=1647, episode=77, episode_return=13.0
# global_step=1670, episode=78, episode_return=22.0
# global_step=1686, episode=79, episode_return=15.0
# global_step=1705, episode=80, episode_return=18.0
# global_step=1724, episode=81, episode_return=18.0
# global_step=1760, episode=82, episode_return=35.0
# global_step=1787, episode=83, episode_return=26.0
# global_step=1804, episode=84, episode_return=16.0
# global_step=1841, episode=85, episode_return=36.0
# global_step=1859, episode=86, episode_return=17.0
# global_step=1882, episode=87, episode_return=22.0
# global_step=1893, episode=88, episode_return=10.0
# global_step=1911, episode=89, episode_return=17.0
# global_step=1922, episode=90, episode_return=10.0
# global_step=1944, episode=91, episode_return=21.0
# global_step=1985, episode=92, episode_return=40.0
# global_step=2018, episode=93, episode_return=32.0
# global_step=2038, episode=94, episode_return=19.0
# global_step=2049, episode=95, episode_return=10.0
# global_step=2063, episode=96, episode_return=13.0
# global_step=2080, episode=97, episode_return=16.0
# global_step=2102, episode=98, episode_return=21.0
# global_step=2119, episode=99, episode_return=16.0
# global_step=2134, episode=100, episode_return=14.0
# global_step=2149, episode=101, episode_return=14.0
# global_step=2194, episode=102, episode_return=44.0
# global_step=2222, episode=103, episode_return=27.0
# global_step=2261, episode=104, episode_return=38.0
# global_step=2281, episode=105, episode_return=19.0
# global_step=2311, episode=106, episode_return=29.0
# global_step=2324, episode=107, episode_return=12.0
# global_step=2334, episode=108, episode_return=9.0
# global_step=2367, episode=109, episode_return=32.0
# global_step=2402, episode=110, episode_return=34.0
# global_step=2416, episode=111, episode_return=13.0
# global_step=2446, episode=112, episode_return=29.0
# global_step=2485, episode=113, episode_return=38.0
# global_step=2507, episode=114, episode_return=21.0
# global_step=2520, episode=115, episode_return=12.0
# global_step=2540, episode=116, episode_return=19.0
# global_step=2553, episode=117, episode_return=12.0
# global_step=2569, episode=118, episode_return=15.0
# global_step=2591, episode=119, episode_return=21.0
# global_step=2605, episode=120, episode_return=13.0
# global_step=2628, episode=121, episode_return=22.0
# global_step=2656, episode=122, episode_return=27.0
# global_step=2671, episode=123, episode_return=14.0
# global_step=2684, episode=124, episode_return=12.0
# global_step=2705, episode=125, episode_return=20.0
# global_step=2752, episode=126, episode_return=46.0
# global_step=2778, episode=127, episode_return=25.0
# global_step=2792, episode=128, episode_return=13.0
# global_step=2811, episode=129, episode_return=18.0
# global_step=2832, episode=130, episode_return=20.0
# global_step=2848, episode=131, episode_return=15.0
# global_step=2859, episode=132, episode_return=10.0
# global_step=2877, episode=133, episode_return=17.0
# global_step=2901, episode=134, episode_return=23.0
# global_step=2920, episode=135, episode_return=18.0
# global_step=2934, episode=136, episode_return=13.0
# global_step=2948, episode=137, episode_return=13.0
# global_step=2979, episode=138, episode_return=30.0
# global_step=2993, episode=139, episode_return=13.0
# global_step=3009, episode=140, episode_return=15.0
# global_step=3027, episode=141, episode_return=17.0
# global_step=3050, episode=142, episode_return=22.0
# global_step=3063, episode=143, episode_return=12.0
# global_step=3077, episode=144, episode_return=13.0
# global_step=3088, episode=145, episode_return=10.0
# global_step=3102, episode=146, episode_return=13.0
# global_step=3112, episode=147, episode_return=9.0
# global_step=3129, episode=148, episode_return=16.0
# global_step=3147, episode=149, episode_return=17.0
# global_step=3161, episode=150, episode_return=13.0
# global_step=3174, episode=151, episode_return=12.0
# global_step=3194, episode=152, episode_return=19.0
# global_step=3209, episode=153, episode_return=14.0
# global_step=3222, episode=154, episode_return=12.0
# global_step=3238, episode=155, episode_return=15.0
# global_step=3258, episode=156, episode_return=19.0
# global_step=3272, episode=157, episode_return=13.0
# global_step=3290, episode=158, episode_return=17.0
# global_step=3303, episode=159, episode_return=12.0
# global_step=3335, episode=160, episode_return=31.0
# global_step=3352, episode=161, episode_return=16.0
# global_step=3371, episode=162, episode_return=18.0
# global_step=3381, episode=163, episode_return=9.0
# global_step=3393, episode=164, episode_return=11.0
# global_step=3403, episode=165, episode_return=9.0
# global_step=3417, episode=166, episode_return=13.0
# global_step=3441, episode=167, episode_return=23.0
# global_step=3457, episode=168, episode_return=15.0
# global_step=3483, episode=169, episode_return=25.0
# global_step=3506, episode=170, episode_return=22.0
# global_step=3517, episode=171, episode_return=10.0
# global_step=3550, episode=172, episode_return=32.0
# global_step=3562, episode=173, episode_return=11.0
# global_step=3577, episode=174, episode_return=14.0
# global_step=3601, episode=175, episode_return=23.0
# global_step=3615, episode=176, episode_return=13.0
# global_step=3647, episode=177, episode_return=31.0
# global_step=3664, episode=178, episode_return=16.0
# global_step=3683, episode=179, episode_return=18.0
# global_step=3698, episode=180, episode_return=14.0
# global_step=3718, episode=181, episode_return=19.0
# global_step=3728, episode=182, episode_return=9.0
# global_step=3748, episode=183, episode_return=19.0
# global_step=3762, episode=184, episode_return=13.0
# global_step=3776, episode=185, episode_return=13.0
# global_step=3790, episode=186, episode_return=13.0
# global_step=3810, episode=187, episode_return=19.0
# global_step=3821, episode=188, episode_return=10.0
# global_step=3833, episode=189, episode_return=11.0
# global_step=3847, episode=190, episode_return=13.0
# global_step=3859, episode=191, episode_return=11.0
# global_step=3890, episode=192, episode_return=30.0
# global_step=3906, episode=193, episode_return=15.0
# global_step=3923, episode=194, episode_return=16.0
# global_step=3938, episode=195, episode_return=14.0
# global_step=3949, episode=196, episode_return=10.0
# global_step=3961, episode=197, episode_return=11.0
# global_step=3982, episode=198, episode_return=20.0
# global_step=3998, episode=199, episode_return=15.0
# global_step=4012, episode=200, episode_return=13.0
# global_step=4025, episode=201, episode_return=12.0
# global_step=4050, episode=202, episode_return=24.0
# global_step=4062, episode=203, episode_return=11.0
# global_step=4075, episode=204, episode_return=12.0
# global_step=4086, episode=205, episode_return=10.0
# global_step=4100, episode=206, episode_return=13.0
# global_step=4111, episode=207, episode_return=10.0
# global_step=4124, episode=208, episode_return=12.0
# global_step=4135, episode=209, episode_return=10.0
# global_step=4147, episode=210, episode_return=11.0
# global_step=4171, episode=211, episode_return=23.0
# global_step=4186, episode=212, episode_return=14.0
# global_step=4206, episode=213, episode_return=19.0
# global_step=4220, episode=214, episode_return=13.0
# global_step=4233, episode=215, episode_return=12.0
# global_step=4246, episode=216, episode_return=12.0
# global_step=4263, episode=217, episode_return=16.0
# global_step=4277, episode=218, episode_return=13.0
# global_step=4287, episode=219, episode_return=9.0
# global_step=4309, episode=220, episode_return=21.0
# global_step=4322, episode=221, episode_return=12.0
# global_step=4337, episode=222, episode_return=14.0
# global_step=4351, episode=223, episode_return=13.0
# global_step=4363, episode=224, episode_return=11.0
# global_step=4378, episode=225, episode_return=14.0
# global_step=4390, episode=226, episode_return=11.0
# global_step=4401, episode=227, episode_return=10.0
# global_step=4413, episode=228, episode_return=11.0
# global_step=4424, episode=229, episode_return=10.0
# global_step=4445, episode=230, episode_return=20.0
# global_step=4464, episode=231, episode_return=18.0
# global_step=4480, episode=232, episode_return=15.0
# global_step=4497, episode=233, episode_return=16.0
# global_step=4515, episode=234, episode_return=17.0
# global_step=4530, episode=235, episode_return=14.0
# global_step=4546, episode=236, episode_return=15.0
# global_step=4562, episode=237, episode_return=15.0
# global_step=4573, episode=238, episode_return=10.0
# global_step=4592, episode=239, episode_return=18.0
# global_step=4604, episode=240, episode_return=11.0
# global_step=4614, episode=241, episode_return=9.0
# global_step=4631, episode=242, episode_return=16.0
# global_step=4641, episode=243, episode_return=9.0
# global_step=4653, episode=244, episode_return=11.0
# global_step=4667, episode=245, episode_return=13.0
# global_step=4676, episode=246, episode_return=8.0
# global_step=4704, episode=247, episode_return=27.0
# global_step=4718, episode=248, episode_return=13.0
# global_step=12069, episode=464, episode_return=114.0
# global_step=12155, episode=465, episode_return=85.0
# global_step=12254, episode=466, episode_return=98.0
# global_step=12314, episode=467, episode_return=59.0
# global_step=12380, episode=468, episode_return=65.0
# global_step=12452, episode=469, episode_return=71.0
# global_step=12612, episode=470, episode_return=159.0
# global_step=12685, episode=471, episode_return=72.0
# global_step=12779, episode=472, episode_return=93.0
# global_step=12896, episode=473, episode_return=116.0
# global_step=12964, episode=474, episode_return=67.0
# steps per second: 2589
# global_step=13076, episode=475, episode_return=111.0
# global_step=13160, episode=476, episode_return=83.0
# global_step=13210, episode=477, episode_return=49.0
# global_step=13306, episode=478, episode_return=95.0
# global_step=13497, episode=479, episode_return=190.0
# global_step=13607, episode=480, episode_return=109.0
# global_step=13800, episode=481, episode_return=192.0
# global_step=13880, episode=482, episode_return=79.0
# steps per second: 2564
# global_step=14025, episode=483, episode_return=144.0
# global_step=14183, episode=484, episode_return=157.0
# global_step=14265, episode=485, episode_return=81.0
# global_step=14343, episode=486, episode_return=77.0
# global_step=14476, episode=487, episode_return=132.0
# global_step=14627, episode=488, episode_return=150.0
# global_step=14718, episode=489, episode_return=90.0
# global_step=14816, episode=490, episode_return=97.0
# global_step=14947, episode=491, episode_return=130.0
# steps per second: 2536
# global_step=15079, episode=492, episode_return=131.0
# global_step=15279, episode=493, episode_return=199.0
# global_step=15385, episode=494, episode_return=105.0
# global_step=15579, episode=495, episode_return=193.0
# global_step=15733, episode=496, episode_return=153.0
# global_step=15989, episode=497, episode_return=255.0
# steps per second: 2521
# global_step=16196, episode=498, episode_return=206.0
# global_step=16684, episode=499, episode_return=487.0
# global_step=16873, episode=500, episode_return=188.0
# steps per second: 2496
# global_step=17123, episode=501, episode_return=249.0
# global_step=17297, episode=502, episode_return=173.0
# global_step=17463, episode=503, episode_return=165.0
# global_step=17673, episode=504, episode_return=209.0
# steps per second: 2489
# global_step=18166, episode=505, episode_return=492.0
# global_step=18443, episode=506, episode_return=276.0
# global_step=18604, episode=507, episode_return=160.0
# global_step=18743, episode=508, episode_return=138.0
# global_step=18934, episode=509, episode_return=190.0
# steps per second: 2472
# global_step=19435, episode=510, episode_return=500.0
# global_step=19865, episode=511, episode_return=429.0
# steps per second: 2461
# global_step=20059, episode=512, episode_return=193.0
# global_step=20444, episode=513, episode_return=384.0
# global_step=20835, episode=514, episode_return=390.0
# steps per second: 2453
# global_step=21311, episode=515, episode_return=475.0
# global_step=21597, episode=516, episode_return=285.0
# steps per second: 2433
# global_step=22098, episode=517, episode_return=500.0
# global_step=22599, episode=518, episode_return=500.0
# steps per second: 2391
# global_step=23100, episode=519, episode_return=500.0
# global_step=23601, episode=520, episode_return=500.0
# global_step=23934, episode=521, episode_return=332.0
# steps per second: 2339
# global_step=24435, episode=522, episode_return=500.0
# global_step=24920, episode=523, episode_return=484.0
# steps per second: 2333
# global_step=25221, episode=524, episode_return=300.0
# global_step=25722, episode=525, episode_return=500.0
# steps per second: 2334
# global_step=26205, episode=526, episode_return=482.0
# global_step=26553, episode=527, episode_return=347.0
# steps per second: 2333
# global_step=27054, episode=528, episode_return=500.0
# global_step=27494, episode=529, episode_return=439.0
# global_step=27785, episode=530, episode_return=290.0
# steps per second: 2329
# global_step=28096, episode=531, episode_return=310.0
# global_step=28471, episode=532, episode_return=374.0
# global_step=28898, episode=533, episode_return=426.0
# steps per second: 2327
# global_step=29289, episode=534, episode_return=390.0
# global_step=29790, episode=535, episode_return=500.0
# steps per second: 2319
# global_step=30291, episode=536, episode_return=500.0
# global_step=30713, episode=537, episode_return=421.0
# steps per second: 2317
# global_step=31012, episode=538, episode_return=298.0
# global_step=31457, episode=539, episode_return=444.0
# global_step=31764, episode=540, episode_return=306.0
# steps per second: 2313
# global_step=32265, episode=541, episode_return=500.0
# global_step=32766, episode=542, episode_return=500.0
# steps per second: 2312
# global_step=33254, episode=543, episode_return=487.0
# global_step=33598, episode=544, episode_return=343.0
# steps per second: 2310
# global_step=34099, episode=545, episode_return=500.0
# global_step=34532, episode=546, episode_return=432.0
# global_step=34756, episode=547, episode_return=223.0
# steps per second: 2311
# global_step=35001, episode=548, episode_return=244.0
# global_step=35240, episode=549, episode_return=238.0
# global_step=35576, episode=550, episode_return=335.0
# steps per second: 2309
# global_step=36056, episode=551, episode_return=479.0
# global_step=36557, episode=552, episode_return=500.0
# steps per second: 2308
# global_step=37058, episode=553, episode_return=500.0
# global_step=37559, episode=554, episode_return=500.0
# steps per second: 2308
# global_step=38022, episode=555, episode_return=462.0
# global_step=38319, episode=556, episode_return=296.0
# global_step=38542, episode=557, episode_return=222.0
# global_step=38985, episode=558, episode_return=442.0
# global_step=38997, episode=559, episode_return=11.0
# steps per second: 2307
# global_step=39009, episode=560, episode_return=11.0
# global_step=39025, episode=561, episode_return=15.0
# global_step=39160, episode=562, episode_return=134.0
# global_step=39661, episode=563, episode_return=500.0
# steps per second: 2307
# global_step=40140, episode=564, episode_return=478.0
# global_step=40402, episode=565, episode_return=261.0
# global_step=40418, episode=566, episode_return=15.0
# global_step=40563, episode=567, episode_return=144.0
# global_step=40574, episode=568, episode_return=10.0
# global_step=40587, episode=569, episode_return=12.0
# global_step=40601, episode=570, episode_return=13.0
# global_step=40618, episode=571, episode_return=16.0
# global_step=40632, episode=572, episode_return=13.0
# global_step=40643, episode=573, episode_return=10.0
# global_step=40653, episode=574, episode_return=9.0
# global_step=40662, episode=575, episode_return=8.0
# global_step=40672, episode=576, episode_return=9.0
# global_step=40681, episode=577, episode_return=8.0
# global_step=40690, episode=578, episode_return=8.0
# global_step=40699, episode=579, episode_return=8.0
# global_step=40709, episode=580, episode_return=9.0
# global_step=40722, episode=581, episode_return=12.0
# global_step=40878, episode=582, episode_return=155.0
# steps per second: 2305
# global_step=41035, episode=583, episode_return=156.0
# global_step=41536, episode=584, episode_return=500.0
# global_step=41725, episode=585, episode_return=188.0
# global_step=41735, episode=586, episode_return=9.0
# global_step=41745, episode=587, episode_return=9.0
# global_step=41754, episode=588, episode_return=8.0
# global_step=41763, episode=589, episode_return=8.0
# global_step=41774, episode=590, episode_return=10.0
# global_step=41786, episode=591, episode_return=11.0
# global_step=41805, episode=592, episode_return=18.0
# global_step=41820, episode=593, episode_return=14.0
# global_step=41830, episode=594, episode_return=9.0
# global_step=41840, episode=595, episode_return=9.0
# global_step=41850, episode=596, episode_return=9.0
# global_step=41860, episode=597, episode_return=9.0
# global_step=41871, episode=598, episode_return=10.0
# global_step=41881, episode=599, episode_return=9.0
# global_step=41892, episode=600, episode_return=10.0
# global_step=41903, episode=601, episode_return=10.0
# global_step=41914, episode=602, episode_return=10.0
# global_step=41926, episode=603, episode_return=11.0
# global_step=41937, episode=604, episode_return=10.0
# global_step=41947, episode=605, episode_return=9.0
# global_step=41957, episode=606, episode_return=9.0
# global_step=41967, episode=607, episode_return=9.0
# steps per second: 2304
# global_step=42468, episode=608, episode_return=500.0
# global_step=42969, episode=609, episode_return=500.0
# steps per second: 2304
# global_step=43470, episode=610, episode_return=500.0
# global_step=43971, episode=611, episode_return=500.0
# steps per second: 2301
# global_step=44472, episode=612, episode_return=500.0
# global_step=44862, episode=613, episode_return=389.0
# steps per second: 2301
# global_step=45363, episode=614, episode_return=500.0
# global_step=45864, episode=615, episode_return=500.0
# steps per second: 2299
# global_step=46365, episode=616, episode_return=500.0
# global_step=46866, episode=617, episode_return=500.0
# steps per second: 2289
# global_step=47367, episode=618, episode_return=500.0
# global_step=47868, episode=619, episode_return=500.0
# steps per second: 2270
# global_step=48369, episode=620, episode_return=500.0
# global_step=48870, episode=621, episode_return=500.0
# steps per second: 2252
# global_step=49371, episode=622, episode_return=500.0
# global_step=49872, episode=623, episode_return=500.0
# max reward achieved

# %%
# close env
envs.close()

# %%
def smooth(x, a=0.1):
    y = [x[0]]
    for xi in x[1:]:
        yi = a * xi + (1 - a) * y[-1]
        y.append(yi)
    return y

# %%
plt.plot(episode_returns, alpha=0.2)
plt.plot(smooth(episode_returns))
plt.title("episode_returns");
plt.show();

# %%
plt.plot(losses)
plt.title("losses");
plt.show();

# %%
# save model
model_path = "dqn_cartpole.pth"
torch.save(q_network.state_dict(), model_path)

# %%
# load model for eval + create test env
envs_eval = gym.vector.SyncVectorEnv([lambda: make_env(env_id, True)])
model = QNetwork(envs_eval)
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()
# Out:
# QNetwork(
#   (network): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=2, bias=True)
#   )
# )

# %%
# evaluate the model
n_episodes_eval = 10
eval_returns = np.zeros(n_episodes_eval)
obs, _ = envs_eval.reset()
for i in range(n_episodes_eval):
  episode_done = False
  while not episode_done:
    q_values = model(np2torch(obs))
    actions = torch.argmax(q_values, dim=1).cpu().numpy()
    obs, rewards, dones, truncateds, infos = envs_eval.step(actions)

    if dones[0] or truncateds[0]:
      G = infos["episode"]["r"][0]
      eval_returns[i] = G
      print(f"episode={i}, return={G}")
      episode_done = True

# close env
envs_eval.close()
# Out:
# episode=0, return=500.0
# episode=1, return=500.0
# episode=2, return=500.0
# episode=3, return=500.0
# episode=4, return=500.0
# episode=5, return=500.0
# episode=6, return=500.0
# episode=7, return=500.0
# episode=8, return=500.0
# episode=9, return=500.0

# %%
# plot the eval returns distribution
plt.hist(eval_returns)
plt.title("Eval Returns")
plt.show();

# %%
# prompt: display video in colab notebook with filename "videos/rl-video-episode-0.mp4"

from IPython.display import HTML
from base64 import b64encode

mp4 = open(f'{video_path}/rl-video-episode-5.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %% [markdown]
# ![](https://deeplearningcourses.com/notebooks_v3_pxl?sc=83SBIReT_VK9g4jXKsbP_w&n=DQN+Cartpole)
