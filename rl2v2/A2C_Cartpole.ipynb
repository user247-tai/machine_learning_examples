# %%
import os
import random
import time

import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

# %%
# settings
env_id  = "CartPole-v1"

# number of environments to run in parallel
num_envs = 4

# total number of timesteps for training over multiple episodes
total_timesteps = 100_000

# adam learning rate
learning_rate = 8e-4

# discount factor
gamma = 0.99

# optional: set seed for reproducibility
# seed = 123
seed = None

# entropy coefficient for loss
entropy_weight = 0.01

# value function coefficient for loss
value_weight = 0.25

# max L2-norm for gradient clipping
max_norm = 0.5

# where to save videos
video_path = "videos_a2c_cartpole"

# %%
# will encapsulate in lambda later
def make_env(env_id, capture_video, seed=None):
    if capture_video:
        env = gym.make(env_id, render_mode="rgb_array")
        env = gym.wrappers.RecordVideo(env, video_path,
            episode_trigger=lambda episode: True)
        # ensure it records all episodes, by default it only records every 1000th
    else:
        env = gym.make(env_id)
    env = gym.wrappers.RecordEpisodeStatistics(env)

    # To get reproducible sampling of actions, a seed can be set with env.action_space.seed(123)
    if seed is not None:
        env.action_space.seed(seed)
    return env

# %%
class ActorCritic(nn.Module):
  def __init__(self, envs, n_hidden=128):
    super().__init__()
    self.network = nn.Sequential(
      nn.Linear(envs.single_observation_space.shape[0], n_hidden),
      nn.ReLU(),
    )

    # Actor / Policy Head
    self.actor = nn.Linear(n_hidden, envs.single_action_space.n)

    # Critic / Value Head
    self.critic = nn.Linear(n_hidden, 1)

  def forward(self, x):
    x = self.network(x)
    return self.actor(x), self.critic(x)

# %%
# make environments
envs = gym.vector.SyncVectorEnv([
    lambda: make_env(
        env_id,
        False,
        seed if seed is None else seed + i) for i in range(num_envs)
])

# %%
# set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# make neural network
ac_network = ActorCritic(envs).to(device)
optimizer = optim.Adam(ac_network.parameters(), lr=learning_rate)

# %%
# sample an action from logits
def sample_action(logits):
  dist = Categorical(logits=logits)
  return dist.sample()

# %%
# compute entropy for loss regularization
def compute_entropy_and_log_prob(logits, actions):
  dist = Categorical(logits=logits)
  return dist.entropy().mean(), dist.log_prob(actions)

# compute entropy for loss regularizaation
def compute_entropy(policy_logits):
    probs = F.softmax(policy_logits, dim=-1)  # Convert logits to probabilities
    log_probs = F.log_softmax(policy_logits, dim=-1)  # Log probabilities
    entropy = -torch.sum(probs * log_probs, dim=-1)  # Compute entropy
    return entropy.mean(), log_probs  # Take mean over batch if needed

# %%
def np2torch(a, dtype=torch.float32, device=device):
  return torch.as_tensor(a, dtype=dtype, device=device)

# %%
# training loop
episode_returns = []
losses = []

# %%
start_time = time.time()
obs, _ = envs.reset(seed=seed)
autoreset = np.zeros(num_envs, dtype=bool)

for global_step in range(total_timesteps):

  # get model output
  action_logits, value = ac_network(np2torch(obs))

  # select action based on current policy
  actions = sample_action(action_logits)
  actions_np = actions.detach().cpu().numpy()

  # take a step in the environment
  next_obs, rewards, dones, truncateds, infos = envs.step(actions_np)

  # record returns for plotting
  for i, (done, truncated) in enumerate(zip(dones, truncateds)):
    if done or truncated:
      ret = infos['episode']['r'][i]
      episode_returns.append(ret)
      print(f"global_step={global_step}, episode={len(episode_returns)}, episode_return={ret}")

  # don't forget
  # note: if autoreset is true, next_obs is s(1)
  obs = next_obs

  ### training! ###
  mask = np.logical_not(autoreset)
  value_ = value[mask]
  obs_ = obs[mask]
  actions_ = actions[mask]
  action_logits_ = action_logits[mask]
  rewards_ = rewards[mask]
  next_obs_ = next_obs[mask]
  dones_ = dones[mask]

  # value loss
  with torch.no_grad():
    _, value_next = ac_network(np2torch(next_obs_))
    td_target = np2torch(rewards_.flatten()) + \
      gamma * np2torch(1 - dones_.flatten()) * value_next.flatten()
  pred = value_.flatten()
  value_loss = F.mse_loss(pred, td_target)

  # policy loss
  # entropy, log_probs = compute_entropy(action_logits_)
  entropy, selected_log_probs = compute_entropy_and_log_prob(
      action_logits_, actions_)
  advantage = td_target - value_
  # log_probs[:, actions]
  # selected_log_probs = log_probs.gather(1, actions_.unsqueeze(1)).squeeze(1)

  # print("log_probs.shape:", log_probs.shape)
  # print("actions_.shape:", actions_.shape)
  # print("selected_log_probs.shape:", selected_log_probs.shape

  policy_loss = -torch.mean(selected_log_probs * advantage.detach())

  # total loss
  loss = policy_loss - entropy_weight * entropy + value_weight * value_loss
  losses.append(loss.item())

  if global_step % 100 == 0:
    print("steps per second:", int(global_step / (time.time() - start_time)))

  # gradient descent step
  optimizer.zero_grad()
  loss.backward()
  # nn.utils.clip_grad_norm_(ac_network.parameters(), max_norm)
  optimizer.step()

  # update autoreset
  autoreset = np.logical_or(dones, truncateds)

  # let's just break if the last 10 episodes had max reward
  if len(episode_returns) > 10 and np.all(np.equal(episode_returns[-10:], 500)):
    print("max reward achieved!")
    break
# Out:
# steps per second: 0
# global_step=12, episode=1, episode_return=13.0
# global_step=14, episode=2, episode_return=15.0
# global_step=16, episode=3, episode_return=17.0
# global_step=18, episode=4, episode_return=19.0
# global_step=27, episode=5, episode_return=12.0
# global_step=30, episode=6, episode_return=13.0
# global_step=41, episode=7, episode_return=10.0
# global_step=41, episode=8, episode_return=13.0
# global_step=48, episode=9, episode_return=35.0
# global_step=52, episode=10, episode_return=10.0
# global_step=58, episode=11, episode_return=39.0
# global_step=58, episode=12, episode_return=16.0
# global_step=76, episode=13, episode_return=27.0
# global_step=76, episode=14, episode_return=17.0
# global_step=90, episode=15, episode_return=13.0
# global_step=94, episode=16, episode_return=17.0
# global_step=98, episode=17, episode_return=45.0
# global_step=99, episode=18, episode_return=40.0
# steps per second: 249
# global_step=104, episode=19, episode_return=13.0
# global_step=109, episode=20, episode_return=14.0
# global_step=112, episode=21, episode_return=12.0
# global_step=118, episode=22, episode_return=13.0
# global_step=120, episode=23, episode_return=10.0
# global_step=121, episode=24, episode_return=22.0
# global_step=126, episode=25, episode_return=13.0
# global_step=130, episode=26, episode_return=9.0
# global_step=134, episode=27, episode_return=12.0
# global_step=136, episode=28, episode_return=9.0
# global_step=140, episode=29, episode_return=9.0
# global_step=146, episode=30, episode_return=27.0
# global_step=146, episode=31, episode_return=11.0
# global_step=146, episode=32, episode_return=9.0
# global_step=150, episode=33, episode_return=9.0
# global_step=157, episode=34, episode_return=10.0
# global_step=158, episode=35, episode_return=11.0
# global_step=159, episode=36, episode_return=12.0
# global_step=169, episode=37, episode_return=9.0
# global_step=169, episode=38, episode_return=10.0
# global_step=169, episode=39, episode_return=18.0
# global_step=170, episode=40, episode_return=12.0
# global_step=179, episode=41, episode_return=9.0
# global_step=179, episode=42, episode_return=9.0
# global_step=182, episode=43, episode_return=12.0
# global_step=183, episode=44, episode_return=12.0
# global_step=190, episode=45, episode_return=10.0
# global_step=192, episode=46, episode_return=12.0
# global_step=193, episode=47, episode_return=10.0
# global_step=194, episode=48, episode_return=10.0
# steps per second: 256
# global_step=203, episode=49, episode_return=10.0
# global_step=203, episode=50, episode_return=8.0
# global_step=205, episode=51, episode_return=14.0
# global_step=208, episode=52, episode_return=14.0
# global_step=213, episode=53, episode_return=9.0
# global_step=215, episode=54, episode_return=11.0
# global_step=217, episode=55, episode_return=11.0
# global_step=217, episode=56, episode_return=8.0
# global_step=223, episode=57, episode_return=9.0
# global_step=228, episode=58, episode_return=10.0
# global_step=228, episode=59, episode_return=12.0
# global_step=231, episode=60, episode_return=13.0
# global_step=234, episode=61, episode_return=10.0
# global_step=239, episode=62, episode_return=10.0
# global_step=240, episode=63, episode_return=11.0
# global_step=244, episode=64, episode_return=12.0
# global_step=245, episode=65, episode_return=10.0
# global_step=250, episode=66, episode_return=10.0
# global_step=252, episode=67, episode_return=11.0
# global_step=254, episode=68, episode_return=9.0
# global_step=256, episode=69, episode_return=10.0
# global_step=262, episode=70, episode_return=11.0
# global_step=264, episode=71, episode_return=11.0
# global_step=266, episode=72, episode_return=9.0
# global_step=268, episode=73, episode_return=13.0
# global_step=272, episode=74, episode_return=9.0
# global_step=275, episode=75, episode_return=8.0
# global_step=278, episode=76, episode_return=13.0
# global_step=281, episode=77, episode_return=12.0
# global_step=282, episode=78, episode_return=9.0
# global_step=286, episode=79, episode_return=10.0
# global_step=291, episode=80, episode_return=12.0
# global_step=291, episode=81, episode_return=9.0
# global_step=292, episode=82, episode_return=9.0
# global_step=296, episode=83, episode_return=9.0
# steps per second: 256
# global_step=301, episode=84, episode_return=8.0
# global_step=302, episode=85, episode_return=10.0
# global_step=302, episode=86, episode_return=10.0
# global_step=306, episode=87, episode_return=9.0
# global_step=311, episode=88, episode_return=9.0
# global_step=312, episode=89, episode_return=9.0
# global_step=313, episode=90, episode_return=10.0
# global_step=317, episode=91, episode_return=10.0
# global_step=322, episode=92, episode_return=9.0
# global_step=322, episode=93, episode_return=8.0
# global_step=323, episode=94, episode_return=11.0
# global_step=327, episode=95, episode_return=9.0
# global_step=331, episode=96, episode_return=8.0
# global_step=331, episode=97, episode_return=8.0
# global_step=334, episode=98, episode_return=10.0
# global_step=336, episode=99, episode_return=8.0
# global_step=340, episode=100, episode_return=8.0
# global_step=342, episode=101, episode_return=10.0
# global_step=343, episode=102, episode_return=8.0
# global_step=347, episode=103, episode_return=10.0
# global_step=350, episode=104, episode_return=9.0
# global_step=352, episode=105, episode_return=9.0
# global_step=353, episode=106, episode_return=9.0
# global_step=358, episode=107, episode_return=10.0
# global_step=361, episode=108, episode_return=10.0
# global_step=362, episode=109, episode_return=8.0
# global_step=365, episode=110, episode_return=12.0
# global_step=368, episode=111, episode_return=9.0
# global_step=371, episode=112, episode_return=9.0
# global_step=373, episode=113, episode_return=10.0
# global_step=376, episode=114, episode_return=10.0
# global_step=378, episode=115, episode_return=9.0
# global_step=381, episode=116, episode_return=9.0
# global_step=382, episode=117, episode_return=8.0
# global_step=386, episode=118, episode_return=9.0
# global_step=388, episode=119, episode_return=9.0
# global_step=391, episode=120, episode_return=9.0
# global_step=393, episode=121, episode_return=10.0
# global_step=396, episode=122, episode_return=9.0
# global_step=398, episode=123, episode_return=9.0
# steps per second: 258
# global_step=402, episode=124, episode_return=10.0
# global_step=402, episode=125, episode_return=8.0
# global_step=406, episode=126, episode_return=9.0
# global_step=409, episode=127, episode_return=10.0
# global_step=412, episode=128, episode_return=9.0
# global_step=413, episode=129, episode_return=10.0
# global_step=415, episode=130, episode_return=8.0
# global_step=419, episode=131, episode_return=9.0
# global_step=423, episode=132, episode_return=10.0
# global_step=424, episode=133, episode_return=10.0
# global_step=425, episode=134, episode_return=9.0
# global_step=430, episode=135, episode_return=10.0
# global_step=433, episode=136, episode_return=9.0
# global_step=434, episode=137, episode_return=9.0
# global_step=435, episode=138, episode_return=9.0
# global_step=440, episode=139, episode_return=9.0
# global_step=443, episode=140, episode_return=9.0
# global_step=444, episode=141, episode_return=9.0
# global_step=446, episode=142, episode_return=10.0
# global_step=450, episode=143, episode_return=9.0
# global_step=452, episode=144, episode_return=8.0
# global_step=455, episode=145, episode_return=10.0
# global_step=455, episode=146, episode_return=8.0
# global_step=460, episode=147, episode_return=9.0
# global_step=464, episode=148, episode_return=11.0
# global_step=464, episode=149, episode_return=8.0
# global_step=465, episode=150, episode_return=9.0
# global_step=470, episode=151, episode_return=9.0
# global_step=474, episode=152, episode_return=9.0
# global_step=476, episode=153, episode_return=10.0
# global_step=477, episode=154, episode_return=12.0
# global_step=481, episode=155, episode_return=10.0
# global_step=486, episode=156, episode_return=11.0
# global_step=487, episode=157, episode_return=10.0
# global_step=488, episode=158, episode_return=10.0
# global_step=490, episode=159, episode_return=8.0
# global_step=496, episode=160, episode_return=8.0
# global_step=497, episode=161, episode_return=10.0
# global_step=498, episode=162, episode_return=9.0
# global_step=499, episode=163, episode_return=8.0
# steps per second: 259
# global_step=506, episode=164, episode_return=9.0
# global_step=508, episode=165, episode_return=10.0
# global_step=509, episode=166, episode_return=10.0
# global_step=510, episode=167, episode_return=10.0
# global_step=515, episode=168, episode_return=8.0
# global_step=519, episode=169, episode_return=10.0
# global_step=519, episode=170, episode_return=9.0
# global_step=520, episode=171, episode_return=9.0
# global_step=525, episode=172, episode_return=9.0
# global_step=529, episode=173, episode_return=8.0
# global_step=529, episode=174, episode_return=9.0
# global_step=529, episode=175, episode_return=9.0
# global_step=535, episode=176, episode_return=9.0
# global_step=540, episode=177, episode_return=10.0
# global_step=540, episode=178, episode_return=10.0
# global_step=540, episode=179, episode_return=10.0
# global_step=742, episode=253, episode_return=11.0
# global_step=748, episode=254, episode_return=12.0
# global_step=749, episode=255, episode_return=9.0
# global_step=753, episode=256, episode_return=16.0
# global_step=756, episode=257, episode_return=13.0
# global_step=757, episode=258, episode_return=8.0
# global_step=761, episode=259, episode_return=11.0
# global_step=766, episode=260, episode_return=12.0
# global_step=768, episode=261, episode_return=11.0
# global_step=770, episode=262, episode_return=12.0
# global_step=772, episode=263, episode_return=10.0
# global_step=778, episode=264, episode_return=9.0
# global_step=782, episode=265, episode_return=11.0
# global_step=786, episode=266, episode_return=13.0
# global_step=793, episode=267, episode_return=14.0
# global_step=796, episode=268, episode_return=13.0
# global_step=797, episode=269, episode_return=10.0
# steps per second: 240
# global_step=803, episode=270, episode_return=36.0
# global_step=804, episode=271, episode_return=10.0
# global_step=809, episode=272, episode_return=11.0
# global_step=814, episode=273, episode_return=17.0
# global_step=814, episode=274, episode_return=10.0
# global_step=815, episode=275, episode_return=10.0
# global_step=822, episode=276, episode_return=12.0
# global_step=825, episode=277, episode_return=10.0
# global_step=825, episode=278, episode_return=10.0
# global_step=826, episode=279, episode_return=10.0
# global_step=835, episode=280, episode_return=12.0
# global_step=836, episode=281, episode_return=10.0
# global_step=836, episode=282, episode_return=10.0
# global_step=837, episode=283, episode_return=10.0
# global_step=847, episode=284, episode_return=11.0
# global_step=848, episode=285, episode_return=11.0
# global_step=848, episode=286, episode_return=11.0
# global_step=848, episode=287, episode_return=10.0
# global_step=858, episode=288, episode_return=10.0
# global_step=859, episode=289, episode_return=10.0
# global_step=859, episode=290, episode_return=10.0
# global_step=861, episode=291, episode_return=12.0
# global_step=869, episode=292, episode_return=10.0
# global_step=870, episode=293, episode_return=10.0
# global_step=870, episode=294, episode_return=10.0
# global_step=872, episode=295, episode_return=10.0
# global_step=880, episode=296, episode_return=10.0
# global_step=881, episode=297, episode_return=10.0
# global_step=882, episode=298, episode_return=11.0
# global_step=885, episode=299, episode_return=12.0
# global_step=889, episode=300, episode_return=8.0
# global_step=892, episode=301, episode_return=9.0
# global_step=893, episode=302, episode_return=11.0
# global_step=896, episode=303, episode_return=10.0
# global_step=899, episode=304, episode_return=9.0
# steps per second: 233
# global_step=905, episode=305, episode_return=12.0
# global_step=905, episode=306, episode_return=11.0
# global_step=909, episode=307, episode_return=9.0
# global_step=910, episode=308, episode_return=13.0
# global_step=915, episode=309, episode_return=9.0
# global_step=919, episode=310, episode_return=13.0
# global_step=920, episode=311, episode_return=9.0
# global_step=920, episode=312, episode_return=10.0
# global_step=925, episode=313, episode_return=9.0
# global_step=929, episode=314, episode_return=9.0
# global_step=931, episode=315, episode_return=10.0
# global_step=933, episode=316, episode_return=12.0
# global_step=936, episode=317, episode_return=10.0
# global_step=941, episode=318, episode_return=9.0
# global_step=942, episode=319, episode_return=12.0
# global_step=944, episode=320, episode_return=10.0
# global_step=947, episode=321, episode_return=10.0
# global_step=950, episode=322, episode_return=8.0
# global_step=954, episode=323, episode_return=11.0
# global_step=954, episode=324, episode_return=9.0
# global_step=958, episode=325, episode_return=10.0
# global_step=961, episode=326, episode_return=10.0
# global_step=965, episode=327, episode_return=10.0
# global_step=966, episode=328, episode_return=11.0
# global_step=969, episode=329, episode_return=10.0
# global_step=974, episode=330, episode_return=8.0
# global_step=976, episode=331, episode_return=14.0
# global_step=977, episode=332, episode_return=10.0
# global_step=984, episode=333, episode_return=9.0
# global_step=984, episode=334, episode_return=14.0
# global_step=986, episode=335, episode_return=9.0
# global_step=990, episode=336, episode_return=12.0
# global_step=994, episode=337, episode_return=9.0
# global_step=997, episode=338, episode_return=12.0
# global_step=998, episode=339, episode_return=11.0
# global_step=1000, episode=340, episode_return=9.0
# steps per second: 224
# global_step=1006, episode=341, episode_return=11.0
# global_step=1006, episode=342, episode_return=8.0
# global_step=1009, episode=343, episode_return=10.0
# global_step=1011, episode=344, episode_return=10.0
# global_step=1016, episode=345, episode_return=9.0
# global_step=1017, episode=346, episode_return=10.0
# global_step=1019, episode=347, episode_return=9.0
# global_step=1022, episode=348, episode_return=10.0
# global_step=1027, episode=349, episode_return=10.0
# global_step=1029, episode=350, episode_return=11.0
# global_step=1030, episode=351, episode_return=10.0
# global_step=1032, episode=352, episode_return=9.0
# global_step=1040, episode=353, episode_return=12.0
# global_step=1041, episode=354, episode_return=10.0
# global_step=1042, episode=355, episode_return=12.0
# global_step=1043, episode=356, episode_return=10.0
# global_step=1052, episode=357, episode_return=11.0
# global_step=1052, episode=358, episode_return=10.0
# global_step=1053, episode=359, episode_return=10.0
# global_step=1053, episode=360, episode_return=9.0
# global_step=1063, episode=361, episode_return=10.0
# global_step=1064, episode=362, episode_return=11.0
# global_step=1064, episode=363, episode_return=10.0
# global_step=1065, episode=364, episode_return=11.0
# global_step=1073, episode=365, episode_return=9.0
# global_step=1075, episode=366, episode_return=9.0
# global_step=1075, episode=367, episode_return=10.0
# global_step=1078, episode=368, episode_return=13.0
# global_step=1084, episode=369, episode_return=10.0
# global_step=1084, episode=370, episode_return=8.0
# global_step=1087, episode=371, episode_return=11.0
# global_step=1088, episode=372, episode_return=9.0
# global_step=1096, episode=373, episode_return=11.0
# global_step=1098, episode=374, episode_return=9.0
# global_step=1098, episode=375, episode_return=10.0
# global_step=1100, episode=376, episode_return=15.0
# steps per second: 223
# global_step=1109, episode=377, episode_return=12.0
# global_step=1109, episode=378, episode_return=10.0
# global_step=1113, episode=379, episode_return=12.0
# global_step=1113, episode=380, episode_return=14.0
# global_step=1120, episode=381, episode_return=10.0
# global_step=1123, episode=382, episode_return=13.0
# global_step=1126, episode=383, episode_return=12.0
# global_step=1131, episode=384, episode_return=10.0
# global_step=1136, episode=385, episode_return=12.0
# global_step=1142, episode=386, episode_return=28.0
# global_step=1146, episode=387, episode_return=14.0
# global_step=1146, episode=388, episode_return=9.0
# global_step=1147, episode=389, episode_return=20.0
# global_step=1161, episode=390, episode_return=14.0
# global_step=1161, episode=391, episode_return=14.0
# global_step=1164, episode=392, episode_return=21.0
# global_step=1176, episode=393, episode_return=14.0
# global_step=1179, episode=394, episode_return=17.0
# global_step=1183, episode=395, episode_return=35.0
# global_step=1188, episode=396, episode_return=11.0
# global_step=1189, episode=397, episode_return=9.0
# global_step=1193, episode=398, episode_return=9.0
# global_step=1196, episode=399, episode_return=31.0
# global_step=1198, episode=400, episode_return=9.0
# steps per second: 225
# global_step=1202, episode=401, episode_return=12.0
# global_step=1207, episode=402, episode_return=8.0
# global_step=1207, episode=403, episode_return=13.0
# global_step=1208, episode=404, episode_return=11.0
# global_step=1218, episode=405, episode_return=10.0
# global_step=1218, episode=406, episode_return=9.0
# global_step=1222, episode=407, episode_return=19.0
# global_step=1222, episode=408, episode_return=14.0
# global_step=1229, episode=409, episode_return=10.0
# global_step=1229, episode=410, episode_return=10.0
# global_step=1232, episode=411, episode_return=9.0
# global_step=1234, episode=412, episode_return=11.0
# global_step=1238, episode=413, episode_return=8.0
# global_step=1243, episode=414, episode_return=10.0
# global_step=1246, episode=415, episode_return=11.0
# global_step=1257, episode=416, episode_return=27.0
# global_step=1257, episode=417, episode_return=10.0
# global_step=1260, episode=418, episode_return=16.0
# global_step=1261, episode=419, episode_return=22.0
# global_step=1266, episode=420, episode_return=8.0
# global_step=1268, episode=421, episode_return=10.0
# global_step=1270, episode=422, episode_return=8.0
# global_step=1270, episode=423, episode_return=9.0
# global_step=1277, episode=424, episode_return=8.0
# global_step=1279, episode=425, episode_return=12.0
# global_step=1283, episode=426, episode_return=12.0
# global_step=1289, episode=427, episode_return=9.0
# global_step=1293, episode=428, episode_return=15.0
# global_step=1295, episode=429, episode_return=24.0
# global_step=1296, episode=430, episode_return=12.0
# global_step=1300, episode=431, episode_return=10.0
# steps per second: 228
# global_step=1307, episode=432, episode_return=10.0
# global_step=1312, episode=433, episode_return=16.0
# global_step=1313, episode=434, episode_return=19.0
# global_step=1320, episode=435, episode_return=12.0
# global_step=1324, episode=436, episode_return=10.0
# global_step=1324, episode=437, episode_return=11.0
# global_step=1327, episode=438, episode_return=26.0
# global_step=1338, episode=439, episode_return=17.0
# global_step=1342, episode=440, episode_return=17.0
# global_step=1343, episode=441, episode_return=18.0
# global_step=1344, episode=442, episode_return=16.0
# global_step=1352, episode=443, episode_return=13.0
# global_step=1354, episode=444, episode_return=10.0
# global_step=1354, episode=445, episode_return=11.0
# global_step=1355, episode=446, episode_return=10.0
# global_step=1363, episode=447, episode_return=10.0
# global_step=1367, episode=448, episode_return=12.0
# global_step=1369, episode=449, episode_return=14.0
# global_step=1375, episode=450, episode_return=11.0
# global_step=1379, episode=451, episode_return=11.0
# global_step=1388, episode=452, episode_return=18.0
# global_step=1389, episode=453, episode_return=33.0
# global_step=1399, episode=454, episode_return=19.0
# global_step=1400, episode=455, episode_return=24.0
# steps per second: 230
# global_step=1406, episode=456, episode_return=17.0
# global_step=1419, episode=457, episode_return=29.0
# global_step=1424, episode=458, episode_return=23.0
# global_step=1426, episode=459, episode_return=26.0
# global_step=1437, episode=460, episode_return=30.0
# global_step=1444, episode=461, episode_return=24.0
# global_step=1448, episode=462, episode_return=23.0
# global_step=1973, episode=531, episode_return=101.0
# global_step=1985, episode=532, episode_return=16.0
# global_step=1995, episode=533, episode_return=24.0
# steps per second: 237
# global_step=2001, episode=534, episode_return=30.0
# global_step=2026, episode=535, episode_return=24.0
# global_step=2033, episode=536, episode_return=59.0
# global_step=2050, episode=537, episode_return=64.0
# global_step=2067, episode=538, episode_return=40.0
# global_step=2084, episode=539, episode_return=50.0
# steps per second: 237
# global_step=2101, episode=540, episode_return=33.0
# global_step=2102, episode=541, episode_return=106.0
# global_step=2114, episode=542, episode_return=29.0
# global_step=2122, episode=543, episode_return=71.0
# global_step=2125, episode=544, episode_return=22.0
# global_step=2129, episode=545, episode_return=14.0
# global_step=2133, episode=546, episode_return=31.0
# global_step=2135, episode=547, episode_return=9.0
# global_step=2137, episode=548, episode_return=14.0
# global_step=2146, episode=549, episode_return=16.0
# global_step=2146, episode=550, episode_return=12.0
# global_step=2159, episode=551, episode_return=12.0
# global_step=2159, episode=552, episode_return=23.0
# global_step=2166, episode=553, episode_return=28.0
# global_step=2184, episode=554, episode_return=24.0
# global_step=2185, episode=555, episode_return=38.0
# global_step=2193, episode=556, episode_return=33.0
# steps per second: 239
# global_step=2212, episode=557, episode_return=45.0
# global_step=2216, episode=558, episode_return=30.0
# global_step=2220, episode=559, episode_return=35.0
# global_step=2242, episode=560, episode_return=25.0
# global_step=2246, episode=561, episode_return=52.0
# global_step=2253, episode=562, episode_return=40.0
# global_step=2271, episode=563, episode_return=24.0
# global_step=2276, episode=564, episode_return=55.0
# global_step=2290, episode=565, episode_return=36.0
# global_step=2298, episode=566, episode_return=26.0
# steps per second: 240
# global_step=2309, episode=567, episode_return=32.0
# global_step=2323, episode=568, episode_return=80.0
# global_step=2327, episode=569, episode_return=36.0
# global_step=2353, episode=570, episode_return=54.0
# global_step=2357, episode=571, episode_return=33.0
# global_step=2372, episode=572, episode_return=44.0
# global_step=2390, episode=573, episode_return=32.0
# global_step=2390, episode=574, episode_return=80.0
# steps per second: 241
# global_step=2416, episode=575, episode_return=25.0
# global_step=2416, episode=576, episode_return=43.0
# global_step=2422, episode=577, episode_return=68.0
# global_step=2443, episode=578, episode_return=26.0
# global_step=2446, episode=579, episode_return=55.0
# global_step=2463, episode=580, episode_return=46.0
# global_step=2464, episode=581, episode_return=20.0
# global_step=2468, episode=582, episode_return=45.0
# global_step=2473, episode=583, episode_return=26.0
# global_step=2489, episode=584, episode_return=25.0
# global_step=2489, episode=585, episode_return=24.0
# global_step=2489, episode=586, episode_return=20.0
# global_step=2492, episode=587, episode_return=18.0
# steps per second: 242
# global_step=2504, episode=588, episode_return=14.0
# global_step=2505, episode=589, episode_return=12.0
# global_step=2506, episode=590, episode_return=16.0
# global_step=2512, episode=591, episode_return=22.0
# global_step=2527, episode=592, episode_return=21.0
# global_step=2528, episode=593, episode_return=23.0
# global_step=2529, episode=594, episode_return=22.0
# global_step=2542, episode=595, episode_return=29.0
# global_step=2549, episode=596, episode_return=21.0
# global_step=2551, episode=597, episode_return=22.0
# global_step=43043, episode=1785, episode_return=229.0
# steps per second: 255
# global_step=43142, episode=1786, episode_return=291.0
# steps per second: 255
# global_step=43253, episode=1787, episode_return=370.0
# global_step=43265, episode=1788, episode_return=347.0
# steps per second: 255
# steps per second: 255
# steps per second: 255
# global_step=43544, episode=1789, episode_return=500.0
# steps per second: 255
# global_step=43643, episode=1790, episode_return=500.0
# steps per second: 255
# global_step=43754, episode=1791, episode_return=500.0
# global_step=43766, episode=1792, episode_return=500.0
# steps per second: 255
# steps per second: 255
# steps per second: 255
# global_step=44045, episode=1793, episode_return=500.0
# steps per second: 255
# global_step=44144, episode=1794, episode_return=500.0
# steps per second: 255
# global_step=44255, episode=1795, episode_return=500.0
# global_step=44267, episode=1796, episode_return=500.0
# steps per second: 256
# steps per second: 256
# steps per second: 256
# global_step=44546, episode=1797, episode_return=500.0
# steps per second: 256
# global_step=44645, episode=1798, episode_return=500.0
# max reward achieved!

# %%
def smooth(x, a=0.1):
    y = [x[0]]
    for xi in x[1:]:
        yi = a * xi + (1 - a) * y[-1]
        y.append(yi)
    return y

# %%
plt.plot(episode_returns, alpha=0.2)
plt.plot(smooth(episode_returns))
plt.title("episode_returns");
plt.show();

# %%
plt.plot(losses)
plt.title("losses");
plt.show();

# %%
# save model
model_path = "a2c_cartpole.pth"
torch.save(ac_network.state_dict(), model_path)

# %%
# load model for eval
envs_eval = gym.vector.SyncVectorEnv([lambda: make_env(env_id, True)])
model = ActorCritic(envs_eval).to(device)
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()
# Out:
# ActorCritic(
#   (network): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU()
#   )
#   (actor): Linear(in_features=128, out_features=2, bias=True)
#   (critic): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
# evaluate model
n_episodes_eval = 10
eval_returns = np.zeros(n_episodes_eval)
obs, _ = envs_eval.reset()
for i in range(n_episodes_eval):
  episode_done = False
  while not episode_done:
    action_logits, _ = model(np2torch(obs))

    # select action based on current policy
    actions = sample_action(action_logits)
    actions_np = actions.detach().cpu().numpy()

    # take a step in the environment
    obs, rewards, dones, truncateds, infos = envs_eval.step(actions_np)

    if dones[0] or truncateds[0]:
      G = infos['episode']['r'][0]
      eval_returns[i] = G
      episode_done = True
      print(f"episode={i}, return={G}")

envs_eval.close()
# Out:
# episode=0, return=500.0
# episode=1, return=500.0
# episode=2, return=500.0
# episode=3, return=500.0
# episode=4, return=500.0
# episode=5, return=500.0
# episode=6, return=500.0
# episode=7, return=500.0
# episode=8, return=500.0
# episode=9, return=500.0

# %%
# plot the eval returns distribution
plt.hist(eval_returns)
plt.title("Eval Returns")
plt.show();

# %%
# prompt: display video in colab notebook with filename "videos/rl-video-episode-0.mp4"

from IPython.display import HTML
from base64 import b64encode

mp4 = open(f'{video_path}/rl-video-episode-0.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %% [markdown]
# ![](https://deeplearningcourses.com/notebooks_v3_pxl?sc=83SBIReT_VK9g4jXKsbP_w&n=A2C+Cartpole)
